# %% [markdown]
# # This notebook is used to run the python code through Jupyter as if it was a command line. So we run python files, and can use commands such as mpirun to run stuff in parallel.
# # Need to put a '!' in front of every command meant for the command line

# %%
from dolfin import *

#Increasing the width of the notebook (visual difference only)
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

#importing mshr for all mesh functions
import mshr as mshr

#have to define where to put plots BEFORE importing matplotlib
# %matplotlib notebook

#Importing matplotlib to plot the results
from matplotlib import pyplot as plt

#Importing numpy to work with arrays
import numpy as np

#Importing time to compute how long each segment takes
import time

#Needed to use the 3D scatter
from mpl_toolkits.mplot3d import Axes3D

#Importing all quantities, constants etc used in the calculations
from MONDquantities import *

#Importing all classes I created
from MONDclasses import *

#Importing the functions I made from the MONDfunctions file
from MONDfunctions import *

#Importing all expressions for weak forms, initial guesses/BCs and sources
from MONDexpressions import *

#Importing the dataframe to loop over from the data_processing file
from data_processing import df
# Out:
# <style>.container { width:100% !important; }</style>

# %%
#Very nice link tutorial for MPI with Python:
#https://rabernat.github.io/research_computing/parallel-programming-with-mpi-for-python.html

#Full MPI documentation for Python:
#https://mpi4py.readthedocs.io/en/stable/

#Creating a group in MPI only including certain processes. Kees said the even ones are the cores, the
#odd ones the other thread available per core, so would be nice to get a communicator of cores only!

#IMPORTANT: It turn out that the error coming from using too much memory doesnt seem to happen when using
#MPI! This error: 'PETSc error code is: 76' This means we can use bigger, better meshes and not be
#limited by memory if we run in parallel

#Converting the notebook to a runnable python file 
# !jupyter nbconvert --to script MONDtest_NoFunctions_MPI.ipynb
# Out:
# [NbConvertApp] Converting notebook data_processing.ipynb to script
# [NbConvertApp] Writing 2583 bytes to data_processing.py

# %%
#Running the full script in parallel using MPI. Optimal number of processes:8. This includes two threads
#per core.

! mpirun -n 8 python3 MONDtest_NoFunctions_MPI.py

#IMPORTANT: when solving for newton_continuous, if we have dregee_PDE = 3 it solves OK.
#However, if we have degree_PDE = 1 we get the error:
#ValueError: zero-size array to reduction operation maximum which has no identity for the 3D plots!
# Out:
# Process 0: Generating mesh with CGAL 3D mesh generator
# Process 0: Computed global bounding box tree with 15 boxes.Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.Process 2: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
#
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.Process 3: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
#
# Process 7: Computed global bounding box tree with 15 boxes.
# Process 0: No Jacobian form specified for nonlinear variational problem.
# Process 0: Differentiating residual form F to obtain Jacobian J = F'.
# Process 1: No Jacobian form specified for nonlinear variational problem.
# Process 1: Differentiating residual form F to obtain Jacobian J = F'.
# Process 3: No Jacobian form specified for nonlinear variational problem.
# Process 3: Differentiating residual form F to obtain Jacobian J = F'.
# Process 4: No Jacobian form specified for nonlinear variational problem.Process 6: No Jacobian form specified for nonlinear variational problem.
# Process 6: Differentiating residual form F to obtain Jacobian J = F'.
# Process 7: No Jacobian form specified for nonlinear variational problem.
# Process 7: Differentiating residual form F to obtain Jacobian J = F'.
# Process 2: No Jacobian form specified for nonlinear variational problem.
# Process 2: Differentiating residual form F to obtain Jacobian J = F'.
# Process 5: No Jacobian form specified for nonlinear variational problem.
# Process 5: Differentiating residual form F to obtain Jacobian J = F'.
#
# Process 4: Differentiating residual form F to obtain Jacobian J = F'.
# Process 0: Solving nonlinear variational problem.
# Process 4: Solving nonlinear variational problem.
# Process 5: Solving nonlinear variational problem.
# Process 7: Solving nonlinear variational problem.
# Process 1: Solving nonlinear variational problem.
# Process 6: Solving nonlinear variational problem.
# Process 2: Solving nonlinear variational problem.
# Process 3: Solving nonlinear variational problem.
#   Process 0: Newton iteration 0: r (abs) = 2.732e+35 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Process 0: Newton iteration 1: r (abs) = 3.715e+20 (tol = 1.000e-10) r (rel) = 1.360e-15 (tol = 1.000e-09)
#   Process 0: Newton solver finished in 1 iterations and 1 linear solver iterations.
# No handles with labels found to put in legend.
# MONDtest_NoFunctions_MPI.py:1097: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# This is process 2 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.7040860652923584 s
#
# The mesh of process 2 has 2748 cells
# Process 2 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2748 to 2819, up by a factor 1.0258369723435226
#
# Iteration 2 of 10: The Cell number went from 2819 to 2754, up by a factor 0.9769421780773324
#
# Iteration 3 of 10: The Cell number went from 2754 to 2969, up by a factor 1.0780682643427741
#
# Iteration 4 of 10: The Cell number went from 2969 to 3015, up by a factor 1.015493432132031
#
# Iteration 5 of 10: The Cell number went from 3015 to 3066, up by a factor 1.0169154228855721
#
# Iteration 6 of 10: The Cell number went from 3066 to 2939, up by a factor 0.9585779517286367
#
# Iteration 7 of 10: The Cell number went from 2939 to 3269, up by a factor 1.11228308948622
#
# Iteration 8 of 10: The Cell number went from 3269 to 3082, up by a factor 0.9427959620679107
#
# Iteration 9 of 10: The Cell number went from 3082 to 3392, up by a factor 1.100584036340039
#
# Iteration 10 of 10: The Cell number went from 3392 to 3574, up by a factor 1.0536556603773586
#
# Cell number went up by a factor 1.3005822416302766
#
# Mesh refined in 0.8087232112884521 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.031092166900634766 s
#
# Starting PDE Solver...
#
# PDE solved in 0.20984768867492676
#
# Collecting data from PDE...
#
# Data collected in 0.11613893508911133 s
#
# Process 2: potential has 808 elements.
# Overall time taken for process 2: 6.1061036586761475 s
#
# MONDtest_NoFunctions_MPI.py:1097: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# This is process 7 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.704132318496704 s
#
# The mesh of process 7 has 2663 cells
# Process 7 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2663 to 2793, up by a factor 1.0488171235448742
#
# Iteration 2 of 10: The Cell number went from 2793 to 2920, up by a factor 1.04547081990691
#
# Iteration 3 of 10: The Cell number went from 2920 to 2954, up by a factor 1.0116438356164383
#
# Iteration 4 of 10: The Cell number went from 2954 to 3061, up by a factor 1.0362220717670954
#
# Iteration 5 of 10: The Cell number went from 3061 to 2955, up by a factor 0.9653707938582162
#
# Iteration 6 of 10: The Cell number went from 2955 to 3213, up by a factor 1.0873096446700508
#
# Iteration 7 of 10: The Cell number went from 3213 to 3117, up by a factor 0.9701213818860878
#
# Iteration 8 of 10: The Cell number went from 3117 to 3198, up by a factor 1.0259865255052936
#
# Iteration 9 of 10: The Cell number went from 3198 to 3396, up by a factor 1.0619136960600375
#
# Iteration 10 of 10: The Cell number went from 3396 to 3583, up by a factor 1.0550647820965842
#
# Cell number went up by a factor 1.345475028163725
#
# Mesh refined in 0.8086917400360107 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.031033992767333984 s
#
# Starting PDE Solver...
#
# PDE solved in 0.20991277694702148
#
# Collecting data from PDE...
#
# Data collected in 0.11633443832397461 s
#
# Process 7: potential has 806 elements.
# Overall time taken for process 7: 6.107303619384766 s
#
# MONDtest_NoFunctions_MPI.py:1097: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# This is process 4 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.704110622406006 s
#
# The mesh of process 4 has 2782 cells
# Process 4 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2782 to 2603, up by a factor 0.9356578001437814
#
# Iteration 2 of 10: The Cell number went from 2603 to 2708, up by a factor 1.0403380714560122
#
# Iteration 3 of 10: The Cell number went from 2708 to 2717, up by a factor 1.0033234859675038
#
# Iteration 4 of 10: The Cell number went from 2717 to 2817, up by a factor 1.0368052999631947
#
# Iteration 5 of 10: The Cell number went from 2817 to 3046, up by a factor 1.0812921547745828
#
# Iteration 6 of 10: The Cell number went from 3046 to 3018, up by a factor 0.9908076165462902
#
# Iteration 7 of 10: The Cell number went from 3018 to 3271, up by a factor 1.0838303512259775
#
# Iteration 8 of 10: The Cell number went from 3271 to 3364, up by a factor 1.0284316722714766
#
# Iteration 9 of 10: The Cell number went from 3364 to 3338, up by a factor 0.9922711058263971
#
# Iteration 10 of 10: The Cell number went from 3338 to 3289, up by a factor 0.9853205512282804
#
# Cell number went up by a factor 1.1822429906542056
#
# Mesh refined in 0.8084213733673096 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.031172752380371094 s
#
# Starting PDE Solver...
#
# PDE solved in 0.20684385299682617
#
# Collecting data from PDE...
#
# Data collected in 0.11611270904541016 s
#
# Process 4: potential has 752 elements.
# Overall time taken for process 4: 6.107508897781372 s
#
# MONDtest_NoFunctions_MPI.py:1097: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# This is process 1 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.701174736022949 s
#
# The mesh of process 1 has 2536 cells
# Process 1 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2536 to 2581, up by a factor 1.0177444794952681
#
# Iteration 2 of 10: The Cell number went from 2581 to 2914, up by a factor 1.1290197597830298
#
# Iteration 3 of 10: The Cell number went from 2914 to 2712, up by a factor 0.9306794783802333
#
# Iteration 4 of 10: The Cell number went from 2712 to 2800, up by a factor 1.0324483775811208
#
# Iteration 5 of 10: The Cell number went from 2800 to 2891, up by a factor 1.0325
#
# Iteration 6 of 10: The Cell number went from 2891 to 2991, up by a factor 1.0345901072293324
#
# Iteration 7 of 10: The Cell number went from 2991 to 3006, up by a factor 1.0050150451354063
#
# Iteration 8 of 10: The Cell number went from 3006 to 3349, up by a factor 1.114105123087159
#
# Iteration 9 of 10: The Cell number went from 3349 to 3142, up by a factor 0.9381905046282473
#
# Iteration 10 of 10: The Cell number went from 3142 to 3262, up by a factor 1.0381922342457033
#
# Cell number went up by a factor 1.2862776025236593
#
# Mesh refined in 0.8088464736938477 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.030882835388183594 s
#
# Starting PDE Solver...
#
# PDE solved in 0.2074146270751953
#
# Collecting data from PDE...
#
# Data collected in 0.11635208129882812 s
#
# Process 1: potential has 677 elements.
# Overall time taken for process 1: 6.1047563552856445 s
#
# MONDtest_NoFunctions_MPI.py:1097: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# This is process 6 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.7041385173797607 s
#
# The mesh of process 6 has 2662 cells
# Process 6 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2662 to 2818, up by a factor 1.058602554470323
#
# Iteration 2 of 10: The Cell number went from 2818 to 2865, up by a factor 1.016678495386799
#
# Iteration 3 of 10: The Cell number went from 2865 to 2954, up by a factor 1.031064572425829
#
# Iteration 4 of 10: The Cell number went from 2954 to 3061, up by a factor 1.0362220717670954
#
# Iteration 5 of 10: The Cell number went from 3061 to 2932, up by a factor 0.9578569095066971
#
# Iteration 6 of 10: The Cell number went from 2932 to 3173, up by a factor 1.0821964529331514
#
# Iteration 7 of 10: The Cell number went from 3173 to 2993, up by a factor 0.9432713520327766
#
# Iteration 8 of 10: The Cell number went from 2993 to 3121, up by a factor 1.042766455061811
#
# Iteration 9 of 10: The Cell number went from 3121 to 3242, up by a factor 1.0387696251201537
#
# Iteration 10 of 10: The Cell number went from 3242 to 3574, up by a factor 1.1024059222702036
#
# Cell number went up by a factor 1.3425995492111196
#
# Mesh refined in 0.8087611198425293 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.030977487564086914 s
#
# Starting PDE Solver...
#
# PDE solved in 0.1917276382446289
#
# Collecting data from PDE...
#
# Data collected in 0.11638069152832031 s
#
# Process 6: potential has 800 elements.
# Overall time taken for process 6: 6.10864782333374 s
#
# MONDtest_NoFunctions_MPI.py:1097: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# This is process 5 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.7040903568267822 s
#
# The mesh of process 5 has 2558 cells
# Process 5 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2558 to 2571, up by a factor 1.0050820953870212
#
# Iteration 2 of 10: The Cell number went from 2571 to 2688, up by a factor 1.0455075845974329
#
# Iteration 3 of 10: The Cell number went from 2688 to 2727, up by a factor 1.0145089285714286
#
# Iteration 4 of 10: The Cell number went from 2727 to 2780, up by a factor 1.0194352768610195
#
# Iteration 5 of 10: The Cell number went from 2780 to 3080, up by a factor 1.1079136690647482
#
# Iteration 6 of 10: The Cell number went from 3080 to 2923, up by a factor 0.949025974025974
#
# Iteration 7 of 10: The Cell number went from 2923 to 3197, up by a factor 1.0937393089291823
#
# Iteration 8 of 10: The Cell number went from 3197 to 3270, up by a factor 1.0228339067876133
#
# Iteration 9 of 10: The Cell number went from 3270 to 3299, up by a factor 1.008868501529052
#
# Iteration 10 of 10: The Cell number went from 3299 to 3296, up by a factor 0.9990906335253107
#
# Cell number went up by a factor 1.2885066458170447
#
# Mesh refined in 0.8087260723114014 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.030957460403442383 s
#
# Starting PDE Solver...
#
# PDE solved in 0.18972206115722656
#
# Collecting data from PDE...
#
# Data collected in 0.11641502380371094 s
#
# Process 5: potential has 755 elements.
# Overall time taken for process 5: 6.110214471817017 s
#
# MONDtest_NoFunctions_MPI.py:1097: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# This is process 0 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.7052650451660156 s
#
# The mesh of process 0 has 2609 cells
# Process 0 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2609 to 2575, up by a factor 0.9869681870448448
#
# Iteration 2 of 10: The Cell number went from 2575 to 2731, up by a factor 1.0605825242718447
#
# Iteration 3 of 10: The Cell number went from 2731 to 2766, up by a factor 1.0128158183815452
#
# Iteration 4 of 10: The Cell number went from 2766 to 2771, up by a factor 1.0018076644974692
#
# Iteration 5 of 10: The Cell number went from 2771 to 2890, up by a factor 1.0429447852760736
#
# Iteration 6 of 10: The Cell number went from 2890 to 3148, up by a factor 1.0892733564013841
#
# Iteration 7 of 10: The Cell number went from 3148 to 3076, up by a factor 0.97712833545108
#
# Iteration 8 of 10: The Cell number went from 3076 to 3349, up by a factor 1.0887516254876464
#
# Iteration 9 of 10: The Cell number went from 3349 to 3215, up by a factor 0.95998805613616
#
# Iteration 10 of 10: The Cell number went from 3215 to 3262, up by a factor 1.0146189735614308
#
# Cell number went up by a factor 1.250287466462246
#
# Mesh refined in 0.8075718879699707 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.03175830841064453 s
#
# Starting PDE Solver...
#
# PDE solved in 0.20987176895141602
#
# Collecting data from PDE...
#
# Data collected in 0.11613845825195312 s
#
# Process 0: potential has 627 elements.
# Process 0: the overall potential has 6010 elements.
# potential_total has length 9015
# potential_total_no_zeros has length 8822
# x_coords has length: 627
# x_coords_total has length: 9015
# x_total_no_zeros has length: 6212
# Overall time taken for process 0: 6.111231803894043 s
#
# MONDtest_NoFunctions_MPI.py:1097: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# This is process 3 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.70413875579834 s
#
# The mesh of process 3 has 2768 cells
# Process 3 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2768 to 2722, up by a factor 0.9833815028901735
#
# Iteration 2 of 10: The Cell number went from 2722 to 2707, up by a factor 0.9944893460690669
#
# Iteration 3 of 10: The Cell number went from 2707 to 2979, up by a factor 1.1004802364240858
#
# Iteration 4 of 10: The Cell number went from 2979 to 3016, up by a factor 1.0124202752601543
#
# Iteration 5 of 10: The Cell number went from 3016 to 3049, up by a factor 1.0109416445623343
#
# Iteration 6 of 10: The Cell number went from 3049 to 3147, up by a factor 1.0321416857986225
#
# Iteration 7 of 10: The Cell number went from 3147 to 3222, up by a factor 1.0238322211630124
#
# Iteration 8 of 10: The Cell number went from 3222 to 3070, up by a factor 0.9528243327126009
#
# Iteration 9 of 10: The Cell number went from 3070 to 3393, up by a factor 1.1052117263843648
#
# Iteration 10 of 10: The Cell number went from 3393 to 3535, up by a factor 1.0418508694370763
#
# Cell number went up by a factor 1.2770953757225434
#
# Mesh refined in 0.8087892532348633 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.030986547470092773 s
#
# Starting PDE Solver...
#
# PDE solved in 0.2098705768585205
#
# Collecting data from PDE...
#
# Data collected in 0.11639070510864258 s
#
# Process 3: potential has 785 elements.
# Overall time taken for process 3: 6.110547780990601 s
# Process 0: Generating mesh with CGAL 3D mesh generator
# Process 0: Computed global bounding box tree with 15 boxes.Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.Process 4: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 0: Computed global bounding box tree with 15 boxes.Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: No Jacobian form specified for nonlinear variational problem.
# Process 0: Differentiating residual form F to obtain Jacobian J = F'.
# Process 1: No Jacobian form specified for nonlinear variational problem.
# Process 1: Differentiating residual form F to obtain Jacobian J = F'.
# Process 2: No Jacobian form specified for nonlinear variational problem.
# Process 2: Differentiating residual form F to obtain Jacobian J = F'.
# Process 3: No Jacobian form specified for nonlinear variational problem.
# Process 3: Differentiating residual form F to obtain Jacobian J = F'.
# Process 4: No Jacobian form specified for nonlinear variational problem.
# Process 4: Differentiating residual form F to obtain Jacobian J = F'.
# Process 5: No Jacobian form specified for nonlinear variational problem.Process 6: No Jacobian form specified for nonlinear variational problem.
# Process 6: Differentiating residual form F to obtain Jacobian J = F'.
# Process 7: No Jacobian form specified for nonlinear variational problem.
# Process 7: Differentiating residual form F to obtain Jacobian J = F'.
#
# Process 5: Differentiating residual form F to obtain Jacobian J = F'.
# Process 0: Solving nonlinear variational problem.
# Process 3: Solving nonlinear variational problem.
# Process 4: Solving nonlinear variational problem.
# Process 6: Solving nonlinear variational problem.
# Process 2: Solving nonlinear variational problem.
# Process 7: Solving nonlinear variational problem.
# Process 1: Solving nonlinear variational problem.
# Process 5: Solving nonlinear variational problem.
#   Process 0: Newton iteration 0: r (abs) = 2.732e+35 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Process 0: Newton iteration 1: r (abs) = 3.701e+20 (tol = 1.000e-10) r (rel) = 1.354e-15 (tol = 1.000e-09)
#   Process 0: Newton solver finished in 1 iterations and 1 linear solver iterations.
# No handles with labels found to put in legend.
# MONDtest_NoFunctions_MPI.py:1097: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# This is process 2 out of 7
# Starting mesh generation...
#
# Mesh generated in 3.1346254348754883 s
#
# The mesh of process 2 has 2748 cells
# Process 2 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2748 to 2819, up by a factor 1.0258369723435226
#
# Iteration 2 of 10: The Cell number went from 2819 to 2754, up by a factor 0.9769421780773324
#
# Iteration 3 of 10: The Cell number went from 2754 to 2969, up by a factor 1.0780682643427741
#
# Iteration 4 of 10: The Cell number went from 2969 to 3015, up by a factor 1.015493432132031
#
# Iteration 5 of 10: The Cell number went from 3015 to 3066, up by a factor 1.0169154228855721
#
# Iteration 6 of 10: The Cell number went from 3066 to 2939, up by a factor 0.9585779517286367
#
# Iteration 7 of 10: The Cell number went from 2939 to 3269, up by a factor 1.11228308948622
#
# Iteration 8 of 10: The Cell number went from 3269 to 3082, up by a factor 0.9427959620679107
#
# Iteration 9 of 10: The Cell number went from 3082 to 3392, up by a factor 1.100584036340039
#
# Iteration 10 of 10: The Cell number went from 3392 to 3574, up by a factor 1.0536556603773586
#
# Cell number went up by a factor 1.3005822416302766
#
# Mesh refined in 0.8543434143066406 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.011655569076538086 s
#
# Starting PDE Solver...
#
# PDE solved in 0.10243487358093262
#
# Collecting data from PDE...
#
# Data collected in 0.12090325355529785 s
#
# Process 2: potential has 808 elements.
# Overall time taken for process 2: 6.394609212875366 s
#
# MONDtest_NoFunctions_MPI.py:1097: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# This is process 7 out of 7
# Starting mesh generation...
#
# Mesh generated in 3.134577512741089 s
#
# The mesh of process 7 has 2663 cells
# Process 7 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2663 to 2793, up by a factor 1.0488171235448742
#
# Iteration 2 of 10: The Cell number went from 2793 to 2920, up by a factor 1.04547081990691
#
# Iteration 3 of 10: The Cell number went from 2920 to 2954, up by a factor 1.0116438356164383
#
# Iteration 4 of 10: The Cell number went from 2954 to 3061, up by a factor 1.0362220717670954
#
# Iteration 5 of 10: The Cell number went from 3061 to 2955, up by a factor 0.9653707938582162
#
# Iteration 6 of 10: The Cell number went from 2955 to 3213, up by a factor 1.0873096446700508
#
# Iteration 7 of 10: The Cell number went from 3213 to 3117, up by a factor 0.9701213818860878
#
# Iteration 8 of 10: The Cell number went from 3117 to 3198, up by a factor 1.0259865255052936
#
# Iteration 9 of 10: The Cell number went from 3198 to 3396, up by a factor 1.0619136960600375
#
# Iteration 10 of 10: The Cell number went from 3396 to 3583, up by a factor 1.0550647820965842
#
# Cell number went up by a factor 1.345475028163725
#
# Mesh refined in 0.8556318283081055 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.010605812072753906 s
#
# Starting PDE Solver...
#
# PDE solved in 0.11535143852233887
#
# Collecting data from PDE...
#
# Data collected in 0.12075304985046387 s
#
# Process 7: potential has 806 elements.
# Overall time taken for process 7: 6.395113229751587 s
#
# MONDtest_NoFunctions_MPI.py:1097: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# MONDtest_NoFunctions_MPI.py:1097: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# This is process 1 out of 7
# Starting mesh generation...
#
# Mesh generated in 3.134687662124634 s
#
# The mesh of process 1 has 2536 cells
# Process 1 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2536 to 2581, up by a factor 1.0177444794952681
#
# Iteration 2 of 10: The Cell number went from 2581 to 2914, up by a factor 1.1290197597830298
#
# Iteration 3 of 10: The Cell number went from 2914 to 2712, up by a factor 0.9306794783802333
#
# Iteration 4 of 10: The Cell number went from 2712 to 2800, up by a factor 1.0324483775811208
#
# Iteration 5 of 10: The Cell number went from 2800 to 2891, up by a factor 1.0325
#
# Iteration 6 of 10: The Cell number went from 2891 to 2991, up by a factor 1.0345901072293324
#
# Iteration 7 of 10: The Cell number went from 2991 to 3006, up by a factor 1.0050150451354063
#
# Iteration 8 of 10: The Cell number went from 3006 to 3349, up by a factor 1.114105123087159
#
# Iteration 9 of 10: The Cell number went from 3349 to 3142, up by a factor 0.9381905046282473
#
# Iteration 10 of 10: The Cell number went from 3142 to 3262, up by a factor 1.0381922342457033
#
# Cell number went up by a factor 1.2862776025236593
#
# Mesh refined in 0.8545913696289062 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.011290311813354492 s
#
# Starting PDE Solver...
#
# PDE solved in 0.11784148216247559
#
# Collecting data from PDE...
#
# Data collected in 0.12078285217285156 s
#
# Process 1: potential has 677 elements.
# Overall time taken for process 1: 6.395629405975342 s
#
# This is process 5 out of 7
# Starting mesh generation...
#
# Mesh generated in 3.1346681118011475 s
#
# The mesh of process 5 has 2558 cells
# Process 5 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2558 to 2571, up by a factor 1.0050820953870212
#
# Iteration 2 of 10: The Cell number went from 2571 to 2688, up by a factor 1.0455075845974329
#
# Iteration 3 of 10: The Cell number went from 2688 to 2727, up by a factor 1.0145089285714286
#
# Iteration 4 of 10: The Cell number went from 2727 to 2780, up by a factor 1.0194352768610195
#
# Iteration 5 of 10: The Cell number went from 2780 to 3080, up by a factor 1.1079136690647482
#
# Iteration 6 of 10: The Cell number went from 3080 to 2923, up by a factor 0.949025974025974
#
# Iteration 7 of 10: The Cell number went from 2923 to 3197, up by a factor 1.0937393089291823
#
# Iteration 8 of 10: The Cell number went from 3197 to 3270, up by a factor 1.0228339067876133
#
# Iteration 9 of 10: The Cell number went from 3270 to 3299, up by a factor 1.008868501529052
#
# Iteration 10 of 10: The Cell number went from 3299 to 3296, up by a factor 0.9990906335253107
#
# Cell number went up by a factor 1.2885066458170447
#
# Mesh refined in 0.8604624271392822 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.005586385726928711 s
#
# Starting PDE Solver...
#
# PDE solved in 0.11670804023742676
#
# Collecting data from PDE...
#
# Data collected in 0.1208961009979248 s
#
# Process 5: potential has 755 elements.
# Overall time taken for process 5: 6.3955302238464355 s
#
# MONDtest_NoFunctions_MPI.py:1097: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# This is process 4 out of 7
# Starting mesh generation...
#
# Mesh generated in 3.134608268737793 s
#
# The mesh of process 4 has 2782 cells
# Process 4 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2782 to 2603, up by a factor 0.9356578001437814
#
# Iteration 2 of 10: The Cell number went from 2603 to 2708, up by a factor 1.0403380714560122
#
# Iteration 3 of 10: The Cell number went from 2708 to 2717, up by a factor 1.0033234859675038
#
# Iteration 4 of 10: The Cell number went from 2717 to 2817, up by a factor 1.0368052999631947
#
# Iteration 5 of 10: The Cell number went from 2817 to 3046, up by a factor 1.0812921547745828
#
# Iteration 6 of 10: The Cell number went from 3046 to 3018, up by a factor 0.9908076165462902
#
# Iteration 7 of 10: The Cell number went from 3018 to 3271, up by a factor 1.0838303512259775
#
# Iteration 8 of 10: The Cell number went from 3271 to 3364, up by a factor 1.0284316722714766
#
# Iteration 9 of 10: The Cell number went from 3364 to 3338, up by a factor 0.9922711058263971
#
# Iteration 10 of 10: The Cell number went from 3338 to 3289, up by a factor 0.9853205512282804
#
# Cell number went up by a factor 1.1822429906542056
#
# Mesh refined in 0.8541610240936279 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.011654138565063477 s
#
# Starting PDE Solver...
#
# PDE solved in 0.10239696502685547
#
# Collecting data from PDE...
#
# Data collected in 0.12048602104187012 s
#
# Process 4: potential has 752 elements.
# Overall time taken for process 4: 6.395792484283447 s
#
# MONDtest_NoFunctions_MPI.py:1097: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# This is process 6 out of 7
# Starting mesh generation...
#
# Mesh generated in 3.134589910507202 s
#
# The mesh of process 6 has 2662 cells
# Process 6 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2662 to 2818, up by a factor 1.058602554470323
#
# Iteration 2 of 10: The Cell number went from 2818 to 2865, up by a factor 1.016678495386799
#
# Iteration 3 of 10: The Cell number went from 2865 to 2954, up by a factor 1.031064572425829
#
# Iteration 4 of 10: The Cell number went from 2954 to 3061, up by a factor 1.0362220717670954
#
# Iteration 5 of 10: The Cell number went from 3061 to 2932, up by a factor 0.9578569095066971
#
# Iteration 6 of 10: The Cell number went from 2932 to 3173, up by a factor 1.0821964529331514
#
# Iteration 7 of 10: The Cell number went from 3173 to 2993, up by a factor 0.9432713520327766
#
# Iteration 8 of 10: The Cell number went from 2993 to 3121, up by a factor 1.042766455061811
#
# Iteration 9 of 10: The Cell number went from 3121 to 3242, up by a factor 1.0387696251201537
#
# Iteration 10 of 10: The Cell number went from 3242 to 3574, up by a factor 1.1024059222702036
#
# Cell number went up by a factor 1.3425995492111196
#
# Mesh refined in 0.8544759750366211 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.011508941650390625 s
#
# Starting PDE Solver...
#
# PDE solved in 0.11779284477233887
#
# Collecting data from PDE...
#
# Data collected in 0.12080192565917969 s
#
# Process 6: potential has 800 elements.
# Overall time taken for process 6: 6.396038770675659 s
#
# MONDtest_NoFunctions_MPI.py:1097: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# This is process 3 out of 7
# Starting mesh generation...
#
# Mesh generated in 3.1347036361694336 s
#
# The mesh of process 3 has 2768 cells
# Process 3 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2768 to 2722, up by a factor 0.9833815028901735
#
# Iteration 2 of 10: The Cell number went from 2722 to 2707, up by a factor 0.9944893460690669
#
# Iteration 3 of 10: The Cell number went from 2707 to 2979, up by a factor 1.1004802364240858
#
# Iteration 4 of 10: The Cell number went from 2979 to 3016, up by a factor 1.0124202752601543
#
# Iteration 5 of 10: The Cell number went from 3016 to 3049, up by a factor 1.0109416445623343
#
# Iteration 6 of 10: The Cell number went from 3049 to 3147, up by a factor 1.0321416857986225
#
# Iteration 7 of 10: The Cell number went from 3147 to 3222, up by a factor 1.0238322211630124
#
# Iteration 8 of 10: The Cell number went from 3222 to 3070, up by a factor 0.9528243327126009
#
# Iteration 9 of 10: The Cell number went from 3070 to 3393, up by a factor 1.1052117263843648
#
# Iteration 10 of 10: The Cell number went from 3393 to 3535, up by a factor 1.0418508694370763
#
# Cell number went up by a factor 1.2770953757225434
#
# Mesh refined in 0.8557388782501221 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.010507583618164062 s
#
# Starting PDE Solver...
#
# PDE solved in 0.11825680732727051
#
# Collecting data from PDE...
#
# Data collected in 0.12089991569519043 s
#
# Process 3: potential has 785 elements.
# Overall time taken for process 3: 6.3975989818573 s
#
# MONDtest_NoFunctions_MPI.py:1097: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# This is process 0 out of 7
# Starting mesh generation...
#
# Mesh generated in 3.1357884407043457 s
#
# The mesh of process 0 has 2609 cells
# Process 0 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2609 to 2575, up by a factor 0.9869681870448448
#
# Iteration 2 of 10: The Cell number went from 2575 to 2731, up by a factor 1.0605825242718447
#
# Iteration 3 of 10: The Cell number went from 2731 to 2766, up by a factor 1.0128158183815452
#
# Iteration 4 of 10: The Cell number went from 2766 to 2771, up by a factor 1.0018076644974692
#
# Iteration 5 of 10: The Cell number went from 2771 to 2890, up by a factor 1.0429447852760736
#
# Iteration 6 of 10: The Cell number went from 2890 to 3148, up by a factor 1.0892733564013841
#
# Iteration 7 of 10: The Cell number went from 3148 to 3076, up by a factor 0.97712833545108
#
# Iteration 8 of 10: The Cell number went from 3076 to 3349, up by a factor 1.0887516254876464
#
# Iteration 9 of 10: The Cell number went from 3349 to 3215, up by a factor 0.95998805613616
#
# Iteration 10 of 10: The Cell number went from 3215 to 3262, up by a factor 1.0146189735614308
#
# Cell number went up by a factor 1.250287466462246
#
# Mesh refined in 0.8529071807861328 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.012649059295654297 s
#
# Starting PDE Solver...
#
# PDE solved in 0.11557197570800781
#
# Collecting data from PDE...
#
# Data collected in 0.12050700187683105 s
#
# Process 0: potential has 627 elements.
# Process 0: the overall potential has 6010 elements.
# potential_total has length 9015
# potential_total_no_zeros has length 8908
# x_coords has length: 627
# x_coords_total has length: 9015
# x_total_no_zeros has length: 9015
# Overall time taken for process 0: 6.399184942245483 s

# %%
#Creating a folder for each set of parameters we use.

x_total_sorted = np.load('Numpy_Arrays/x_sorted_saved.npy')
y_total_sorted = np.load('Numpy_Arrays/y_sorted_saved.npy')
z_total_sorted = np.load('Numpy_Arrays/z_sorted_saved.npy')
r_total_sorted = np.load('Numpy_Arrays/r_sorted_saved.npy')
potential_total_sorted = np.load('Numpy_Arrays/potential_saved.npy')
source_total_sorted = np.load('Numpy_Arrays/source_saved.npy')
apparent_mass_total_sorted = np.load('Numpy_Arrays/apparent_mass_saved.npy')
dark_mass_total_sorted = np.load('Numpy_Arrays/dark_mass_saved.npy')

# %%
#Defining the radius of the Gaussian containing 99.7% of the total mass
radius_tot = stand_dev_peak/3

#Analytic potential for a MOND homogeneous sphere (good approximation to Gaussian, peaked or wide)
potential_dirac_MOND= sqrt(G*mgb*a0)*np.log(r_total_sorted)

#Analytic potential for a MOND homogeneous sphere. Adding MOND potential at boundary for the offset
potential_sphere_MOND = (np.heaviside(r_total_sorted - radius_tot, 0.5)*sqrt(G*mgb*a0)*np.log(r_total_sorted) +
(np.heaviside(radius_tot - r_total_sorted, 0.5))*(4/3*sqrt(pi/3*a0*G*mgb/volume_out)*np.power(r_total_sorted,3/2)+
sqrt(G*mgb*a0)*ln(radius_tot) - 4/3*sqrt(pi/3*a0*G*mgb/volume_out)*radius_tot**(3/2)))

#Potential for a homogeneous sphere in Newton
potential_sphere_Newton = (np.heaviside(r_total_sorted - radius_tot, 0.5)*(-G*mgb/r_total_sorted) +
(np.heaviside(radius_tot - r_total_sorted, 0.5))*G*mgb/(2*radius_tot**3)*(r_total_sorted**2-
3*radius_tot**2)+sqrt(G*mgb*a0)*ln(domain_size))

#Plotting radial FEM solution and analytic solution on the same plot. We use subplots so'
#we can put multiple axes on the same plot and plot different scales
fig, potential1 = plt.subplots(sharex=True, sharey=True)

color = 'tab:red'
potential1.set_ylabel('FEM', color=color)

potential1.scatter(x_total_sorted, potential_total_sorted, marker = '.', s = 0.5, c = y_total_sorted/y_total_sorted.max(), cmap = 'jet')

potential1.tick_params(axis='y', labelcolor=color)

#UNCOMMENT TO HAVE SEPARATE AXES TO COMPARE SHAPES
# potential2 = potential1.twinx()
color = 'tab:blue'
# potential2.set_ylabel('Analytic', color=color)
plt.plot(r_total_sorted, potential_sphere_MOND, label = 'Homogeneous Sphere MOND', linestyle = '--')
plt.plot(r_total_sorted, potential_sphere_Newton, label = 'Homogeneous Sphere Newton', linestyle = '--')

#It is possible to use Latex directly in the labels by enclosing expressions in $$
# plt.ylabel('$\phi$')

plot_annotations(potential1)

#Formatting plot using the function I made
plot_format(potential1,1,0)

potential1_title = f'potential_1_p'

#Saving the figure in the Figure folder, removed padding arounf with bbox_inches and. This is executed
#by each process, so uncomment if need to see solution from each process separately
# plt.savefig(f'Figures/{potential1_title}.pdf', bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
mgb/(4*pi/3*domain_size**3)
# Out:
# 2.447731038318541e-25

# %%
#Creating objects for plotting
baryonic_mass_object = plot_quantity(source_total_sorted, 'Baryonic', 'r', 2)
apparent_mass_object = plot_quantity(apparent_mass_total_sorted, 'Apparent', 'b', baryonic_mass_object.width/2)
dark_mass_object = plot_quantity(dark_mass_total_sorted, 'Dark', 'g', baryonic_mass_object.width/2)

#Declaring figure with 3 subplots
fig, apparent_mass_plot = plt.subplots(1,3,sharex=True,sharey=True, tight_layout=True)

# #Title of the overall plot
# plt.title('Mass Distributions')

#Limit in the y axis for all subplots
apparent_mass_ylim = (1.1*apparent_mass_total_sorted.min(), 1.1*apparent_mass_total_sorted.max())

# Limits fixed from max and min of the apparent mass density, with 10% free extra space
plt.ylim(1.1*dark_mass_total_sorted.min(), 1.1*apparent_mass_total_sorted.max())  

plot_together = True

for i, distribution in enumerate([baryonic_mass_object, apparent_mass_object, dark_mass_object]):
#First subplot for the baryonic mass distribution
    (apparent_mass_plot[i].scatter(x_total_sorted, distribution.quantity,  marker = '.', s = 1,
    c = y_total_sorted/y_total_sorted.max(), cmap = 'jet'))
    
    #Title of the subplot
    apparent_mass_plot[i]. set_title(distribution.title)
    
    #format each subplot
    plot_format(apparent_mass_plot[i],1,0)

#Integrating the baryonic distribution radially
baryonic_mass_integrated = np.trapz(apparent_mass_total_sorted*4*pi*r_total_sorted**2, x = r_total_sorted)

#Calculating the total mass by integrating the distribution radially
apparent_mass_integrated = np.trapz(apparent_mass_total_sorted*4*pi*r_total_sorted**2, x = r_total_sorted)

#The total dark matter is given by the difference of apparent and baryonic masses
dark_mass_integrated = apparent_mass_integrated - baryonic_mass_integrated

#Ratio between the integrated baryonic density and the total mass. Should be 1
baryonic_integrated_ratio = baryonic_mass_integrated/mgb

#Ratio between the dark matter and the total mass
dark_integrated_ratio = dark_mass_integrated/mgb

#Ratio between the dark matter and baryonic matter, should be exact same as dark_intergrated_ratio!
dark_baryonic_ratio = dark_mass_integrated/baryonic_mass_integrated

print(f'The mass should be: {mgb/(10**14*ms)}MS. It is {baryonic_mass_integrated/(10**14*ms)}MS\nThe ratio of the integrated masses are:\n baryonic integrated/'
      f'correct mass: {baryonic_integrated_ratio}. This should be 1 \n'
      f'Dark mass/baryonic mass = {dark_integrated_ratio}\n'
      f'Dark mass/ baryonic integrated = {dark_baryonic_ratio}')
# Out:
# <img src="data:image/png;base64,..." width="640">
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# The mass should be: 1.13MS. It is 0.0MS
# The ratio of the integrated masses are:
#  baryonic integrated/correct mass: 0.0. This should be 1
# Dark mass/baryonic mass = 0.0
# Dark mass/ baryonic integrated = nan
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:47: RuntimeWarning: invalid value encountered in double_scalars

# %%
beta_mass = (np.trapz(rho_0/(1+(r_total_sorted/r_c)**2)**(3*beta/2)*4*pi*r_total_sorted**2,
                      x = r_total_sorted))

beta_mass_c = (np.trapz(rho_0/(pow(1+(pow(r_total_sorted,2))/pow(r_c,2), 3*beta/2))*4*pi*r_total_sorted**2,
                      x = r_total_sorted)) 

beta_mass/mgb
# Out:
# 0.98039689495446003

# %%
#Declaring the parameters needed for the Navarro Frenk White distribution
#The density scale
rho_0_NFW = rho_0

#The scale radius
R_s = r_c

#Analytical formula for the Navarro Frenk White distribution
NFW_distribution = rho_0/((r_total_sorted/R_s)*(1 + r_total_sorted/R_s)**2)

#The difference between apparent mass and baryonic mass is the dark matter distribution
dark_matter_total_sorted = (apparent_mass_total_sorted-source_total_sorted)

fig, dark_matter_density_plot = plt.subplots()

#Plotting al distributions
for i, distribution in enumerate([apparent_mass_object, dark_mass_object, baryonic_mass_object]):

    #Plotting using the plot_quantity object as for cell above. Using loglog here
    (dark_matter_density_plot.plot(r_total_sorted, distribution.quantity, c = distribution.color,
                                   linewidth = distribution.width, label = distribution.title))

#Limits fixed from max and min of the apparent mass density, with 10% free extra space
plt.ylim(1.1*dark_mass_total_sorted.min(), 1.1*apparent_mass_total_sorted.max())    

#Plotting a Navarro Frenk White dark matter distribution on the same graph but not same axis, so it's
#scale independent
NFW_profile_plot = dark_matter_density_plot.twinx()
color = 'tab:blue'

dark_matter_density_plot.plot(r_total_sorted, NFW_distribution, label = 'NFW profile', linestyle = '--', color='y')

plt.title('Dark Matter Distribution')
# plot_annotations(dark_matter_density_plot)
plot_format(dark_matter_density_plot,1,1)
# Out:
# <img src="data:image/png;base64,..." width="640">
# No handles with labels found to put in legend.
