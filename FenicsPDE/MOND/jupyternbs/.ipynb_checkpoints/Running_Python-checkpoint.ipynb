# %% [markdown]
# # This notebook is used to run the python code through Jupyter as if it was a command line. So we run python files, and can use commands such as mpirun to run stuff in parallel.
# # Need to put a '!' in front of every command meant for the command line

# %%
from dolfin import *

#Increasing the width of the notebook (visual difference only)
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

#importing mshr for all mesh functions
import mshr as mshr

#have to define where to put plots BEFORE importing matplotlib
# %matplotlib notebook

#Importing matplotlib to plot the results
from matplotlib import pyplot as plt

#Importing numpy to work with arrays
import numpy as np

#Importing time to compute how long each segment takes
import time

#Needed to use the 3D scatter
from mpl_toolkits.mplot3d import Axes3D

#Importing all quantities, constants etc used in the calculations
from MONDquantities import *

#Importing all classes I created
from MONDclasses import *

#Importing the functions I made from the MONDfunctions file
from MONDfunctions import *

#Importing all expressions for weak forms, initial guesses/BCs and sources
from MONDexpressions import *
# Out:
# <style>.container { width:100% !important; }</style>

# %%
#Very nice link tutorial for MPI with Python:
#https://rabernat.github.io/research_computing/parallel-programming-with-mpi-for-python.html

#Full MPI documentation for Python:
#https://mpi4py.readthedocs.io/en/stable/

#Creating a group in MPI only including certain processes. Kees said the even ones are the cores, the
#odd ones the other thread available per core, so would be nice to get a communicator of cores only!

#IMPORTANT: It turn out that the error coming from using too much memory doesnt seem to happen when using
#MPI! This error: 'PETSc error code is: 76' This means we can use bigger, better meshes and not be
#limited by memory if we run in parallel

#Converting the notebook to a runnable python file 
# !jupyter nbconvert --to script MONDtest_NoFunctions_MPI.ipynb
# Out:
# [NbConvertApp] Converting notebook MONDtest_NoFunctions_MPI.ipynb to script
# [NbConvertApp] Writing 51833 bytes to MONDtest_NoFunctions_MPI.py

# %%
#Running the full script in parallel using MPI. Optimal number of processes:8. This includes two threads
#per core.
! mpirun -n 8 python3 MONDtest_NoFunctions_MPI.py

#IMPORTANT: when solving for newton_continuous, if we have dregee_PDE = 3 it solves OK.
#However, if we have degree_PDE = 1 we get the error:
#ValueError: zero-size array to reduction operation maximum which has no identity for the 3D plots!
# Out:
# Process 0: Generating mesh with CGAL 3D mesh generator
# Process 0: Computed global bounding box tree with 15 boxes.Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: No Jacobian form specified for nonlinear variational problem.
# Process 0: Differentiating residual form F to obtain Jacobian J = F'.
# Process 3: No Jacobian form specified for nonlinear variational problem.Process 4: No Jacobian form specified for nonlinear variational problem.
# Process 4: Differentiating residual form F to obtain Jacobian J = F'.
# Process 5: No Jacobian form specified for nonlinear variational problem.
# Process 5: Differentiating residual form F to obtain Jacobian J = F'.
# Process 6: No Jacobian form specified for nonlinear variational problem.
# Process 6: Differentiating residual form F to obtain Jacobian J = F'.
# Process 7: No Jacobian form specified for nonlinear variational problem.
# Process 7: Differentiating residual form F to obtain Jacobian J = F'.
# Process 2: No Jacobian form specified for nonlinear variational problem.
# Process 2: Differentiating residual form F to obtain Jacobian J = F'.
#
# Process 3: Differentiating residual form F to obtain Jacobian J = F'.Process 1: No Jacobian form specified for nonlinear variational problem.
#
# Process 1: Differentiating residual form F to obtain Jacobian J = F'.
# Process 0: Solving nonlinear variational problem.
# Process 1: Solving nonlinear variational problem.
# Process 3: Solving nonlinear variational problem.
# Process 4: Solving nonlinear variational problem.
# Process 5: Solving nonlinear variational problem.
# Process 6: Solving nonlinear variational problem.
# Process 2: Solving nonlinear variational problem.
# Process 7: Solving nonlinear variational problem.
#   Process 0: Newton iteration 0: r (abs) = 3.663e+33 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Process 0: Newton iteration 1: r (abs) = 2.787e+38 (tol = 1.000e-10) r (rel) = 7.607e+04 (tol = 1.000e-09)
#   Process 0: Newton iteration 2: r (abs) = 5.932e+31 (tol = 1.000e-10) r (rel) = 1.619e-02 (tol = 1.000e-09)
#   Process 0: Newton iteration 3: r (abs) = 1.487e+30 (tol = 1.000e-10) r (rel) = 4.059e-04 (tol = 1.000e-09)
#   Process 0: Newton iteration 4: r (abs) = 1.601e+29 (tol = 1.000e-10) r (rel) = 4.369e-05 (tol = 1.000e-09)
#   Process 0: Newton iteration 5: r (abs) = 3.732e+28 (tol = 1.000e-10) r (rel) = 1.019e-05 (tol = 1.000e-09)
#   Process 0: Newton iteration 6: r (abs) = 7.890e+27 (tol = 1.000e-10) r (rel) = 2.154e-06 (tol = 1.000e-09)
#   Process 0: Newton iteration 7: r (abs) = 1.122e+27 (tol = 1.000e-10) r (rel) = 3.062e-07 (tol = 1.000e-09)
#   Process 0: Newton iteration 8: r (abs) = 6.932e+25 (tol = 1.000e-10) r (rel) = 1.892e-08 (tol = 1.000e-09)
#   Process 0: Newton iteration 9: r (abs) = 1.743e+24 (tol = 1.000e-10) r (rel) = 4.758e-10 (tol = 1.000e-09)
#   Process 0: Newton solver finished in 9 iterations and 9 linear solver iterations.
# No handles with labels found to put in legend.
# MONDtest_NoFunctions_MPI.py:1042: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# This is process 2 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.8777973651885986 s
#
# The mesh of process 2 has 2641 cells
# Process 2 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2641 to 2680, up by a factor 1.0147671336614918
#
# Iteration 2 of 10: The Cell number went from 2680 to 2831, up by a factor 1.0563432835820896
#
# Iteration 3 of 10: The Cell number went from 2831 to 2658, up by a factor 0.9388908512892971
#
# Iteration 4 of 10: The Cell number went from 2658 to 2876, up by a factor 1.0820165537998494
#
# Iteration 5 of 10: The Cell number went from 2876 to 2761, up by a factor 0.9600139082058414
#
# Iteration 6 of 10: The Cell number went from 2761 to 3114, up by a factor 1.1278522274538212
#
# Iteration 7 of 10: The Cell number went from 3114 to 2954, up by a factor 0.9486191393705845
#
# Iteration 8 of 10: The Cell number went from 2954 to 3187, up by a factor 1.0788761002031144
#
# Iteration 9 of 10: The Cell number went from 3187 to 3259, up by a factor 1.0225917791026042
#
# Iteration 10 of 10: The Cell number went from 3259 to 3565, up by a factor 1.093893832463946
#
# Cell number went up by a factor 1.3498674744414993
#
# Mesh refined in 0.8821291923522949 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.03649163246154785 s
#
# Starting PDE Solver...
#
# PDE solved in 34.64076566696167
#
# Collecting data from PDE...
#
# Data collected in 1.3628370761871338 s
#
# Process 2: potential has 798 elements.
# Overall time taken for process 2: 42.25400352478027 s
#
# MONDtest_NoFunctions_MPI.py:1042: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# MONDtest_NoFunctions_MPI.py:1042: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# This is process 3 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.877566337585449 s
#
# The mesh of process 3 has 2711 cells
# Process 3 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2711 to 2660, up by a factor 0.9811877535964588
#
# Iteration 2 of 10: The Cell number went from 2660 to 2631, up by a factor 0.9890977443609023
#
# Iteration 3 of 10: The Cell number went from 2631 to 2697, up by a factor 1.025085518814139
#
# Iteration 4 of 10: The Cell number went from 2697 to 2827, up by a factor 1.0482017055988135
#
# Iteration 5 of 10: The Cell number went from 2827 to 2894, up by a factor 1.023700035373187
#
# Iteration 6 of 10: The Cell number went from 2894 to 2904, up by a factor 1.0034554250172771
#
# Iteration 7 of 10: The Cell number went from 2904 to 2951, up by a factor 1.0161845730027548
#
# Iteration 8 of 10: The Cell number went from 2951 to 3378, up by a factor 1.1446967129786514
#
# Iteration 9 of 10: The Cell number went from 3378 to 3260, up by a factor 0.9650680876258141
#
# Iteration 10 of 10: The Cell number went from 3260 to 3579, up by a factor 1.0978527607361963
#
# Cell number went up by a factor 1.3201770564367392
#
# Mesh refined in 0.8818042278289795 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.03667712211608887 s
#
# Starting PDE Solver...
#
# PDE solved in 34.64067792892456
#
# Collecting data from PDE...
#
# Data collected in 1.362764596939087 s
#
# Process 3: potential has 806 elements.
# Overall time taken for process 3: 42.25982666015625 s
#
# MONDtest_NoFunctions_MPI.py:1042: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# This is process 6 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.8889553546905518 s
#
# The mesh of process 6 has 2777 cells
# Process 6 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2777 to 2624, up by a factor 0.9449045732805186
#
# Iteration 2 of 10: The Cell number went from 2624 to 2686, up by a factor 1.0236280487804879
#
# Iteration 3 of 10: The Cell number went from 2686 to 2888, up by a factor 1.075204765450484
#
# Iteration 4 of 10: The Cell number went from 2888 to 2832, up by a factor 0.9806094182825484
#
# Iteration 5 of 10: The Cell number went from 2832 to 2758, up by a factor 0.9738700564971752
#
# Iteration 6 of 10: The Cell number went from 2758 to 3054, up by a factor 1.107324147933285
#
# Iteration 7 of 10: The Cell number went from 3054 to 2974, up by a factor 0.9738048461034708
#
# Iteration 8 of 10: The Cell number went from 2974 to 3123, up by a factor 1.0501008742434432
#
# Iteration 9 of 10: The Cell number went from 3123 to 3342, up by a factor 1.0701248799231509
#
# Iteration 10 of 10: The Cell number went from 3342 to 3359, up by a factor 1.0050867743865948
#
# Cell number went up by a factor 1.2095786820309686
#
# Mesh refined in 0.8819453716278076 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.036168813705444336 s
#
# Starting PDE Solver...
#
# PDE solved in 34.64081788063049
#
# Collecting data from PDE...
#
# Data collected in 1.3628265857696533 s
#
# Process 6: potential has 769 elements.
# Overall time taken for process 6: 42.2710907459259 s
#
# This is process 7 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.8887689113616943 s
#
# The mesh of process 7 has 2777 cells
# Process 7 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2777 to 2811, up by a factor 1.0122434281598847
#
# Iteration 2 of 10: The Cell number went from 2811 to 2707, up by a factor 0.9630024902170046
#
# Iteration 3 of 10: The Cell number went from 2707 to 2889, up by a factor 1.0672330993719985
#
# Iteration 4 of 10: The Cell number went from 2889 to 2886, up by a factor 0.9989615784008308
#
# Iteration 5 of 10: The Cell number went from 2886 to 2755, up by a factor 0.9546084546084546
#
# Iteration 6 of 10: The Cell number went from 2755 to 3048, up by a factor 1.1063520871143375
#
# Iteration 7 of 10: The Cell number went from 3048 to 3041, up by a factor 0.9977034120734908
#
# Iteration 8 of 10: The Cell number went from 3041 to 3091, up by a factor 1.016441959881618
#
# Iteration 9 of 10: The Cell number went from 3091 to 3555, up by a factor 1.1501132319637657
#
# Iteration 10 of 10: The Cell number went from 3555 to 3423, up by a factor 0.9628691983122363
#
# Cell number went up by a factor 1.2326251350378106
#
# Mesh refined in 0.8823883533477783 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.03632354736328125 s
#
# Starting PDE Solver...
#
# PDE solved in 34.64072370529175
#
# Collecting data from PDE...
#
# Data collected in 1.3627924919128418 s
#
# Process 7: potential has 783 elements.
# Overall time taken for process 7: 42.271220445632935 s
#
# MONDtest_NoFunctions_MPI.py:1042: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# MONDtest_NoFunctions_MPI.py:1042: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# This is process 0 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.889754056930542 s
#
# The mesh of process 0 has 2604 cells
# Process 0 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2604 to 2618, up by a factor 1.0053763440860215
#
# Iteration 2 of 10: The Cell number went from 2618 to 2659, up by a factor 1.0156608097784567
#
# Iteration 3 of 10: The Cell number went from 2659 to 2763, up by a factor 1.0391124482888303
#
# Iteration 4 of 10: The Cell number went from 2763 to 2741, up by a factor 0.9920376402461093
#
# Iteration 5 of 10: The Cell number went from 2741 to 2957, up by a factor 1.0788033564392558
#
# Iteration 6 of 10: The Cell number went from 2957 to 2882, up by a factor 0.9746364558674332
#
# Iteration 7 of 10: The Cell number went from 2882 to 3180, up by a factor 1.1034004163775155
#
# Iteration 8 of 10: The Cell number went from 3180 to 3236, up by a factor 1.0176100628930818
#
# Iteration 9 of 10: The Cell number went from 3236 to 3557, up by a factor 1.0991965389369591
#
# Iteration 10 of 10: The Cell number went from 3557 to 3379, up by a factor 0.9499578296317122
#
# Cell number went up by a factor 1.2976190476190477
#
# Mesh refined in 0.8820385932922363 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.03651833534240723 s
#
# Starting PDE Solver...
#
# PDE solved in 34.64048886299133
#
# Collecting data from PDE...
#
# Data collected in 1.3628382682800293 s
#
# Process 0: potential has 780 elements.
# Process 0: the overall potential has 6143 elements.
# potential_total has length 9214
# potential_total_no_zeros has length 9212
# x_coords has length: 780
# x_coords_total has length: 9214
# x_total_no_zeros has length: 8409
# Overall time taken for process 0: 42.27435040473938 s
#
# This is process 4 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.8886053562164307 s
#
# The mesh of process 4 has 2535 cells
# Process 4 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2535 to 2621, up by a factor 1.0339250493096648
#
# Iteration 2 of 10: The Cell number went from 2621 to 2742, up by a factor 1.0461655856543304
#
# Iteration 3 of 10: The Cell number went from 2742 to 2646, up by a factor 0.9649890590809628
#
# Iteration 4 of 10: The Cell number went from 2646 to 2742, up by a factor 1.036281179138322
#
# Iteration 5 of 10: The Cell number went from 2742 to 3021, up by a factor 1.1017505470459519
#
# Iteration 6 of 10: The Cell number went from 3021 to 2971, up by a factor 0.9834491890102615
#
# Iteration 7 of 10: The Cell number went from 2971 to 3221, up by a factor 1.0841467519353754
#
# Iteration 8 of 10: The Cell number went from 3221 to 3400, up by a factor 1.055572803477181
#
# Iteration 9 of 10: The Cell number went from 3400 to 3304, up by a factor 0.971764705882353
#
# Iteration 10 of 10: The Cell number went from 3304 to 3557, up by a factor 1.0765738498789346
#
# Cell number went up by a factor 1.403155818540434
#
# Mesh refined in 0.8817934989929199 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.03626227378845215 s
#
# Starting PDE Solver...
#
# PDE solved in 34.640931367874146
#
# Collecting data from PDE...
#
# Data collected in 1.3627572059631348 s
#
# Process 4: potential has 735 elements.
# Overall time taken for process 4: 42.27311563491821 s
#
# MONDtest_NoFunctions_MPI.py:1042: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# This is process 5 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.8885703086853027 s
#
# The mesh of process 5 has 2552 cells
# Process 5 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2552 to 2708, up by a factor 1.061128526645768
#
# Iteration 2 of 10: The Cell number went from 2708 to 2686, up by a factor 0.9918759231905465
#
# Iteration 3 of 10: The Cell number went from 2686 to 2666, up by a factor 0.992553983618764
#
# Iteration 4 of 10: The Cell number went from 2666 to 2798, up by a factor 1.0495123780945237
#
# Iteration 5 of 10: The Cell number went from 2798 to 2957, up by a factor 1.0568263045032167
#
# Iteration 6 of 10: The Cell number went from 2957 to 2851, up by a factor 0.9641528576259722
#
# Iteration 7 of 10: The Cell number went from 2851 to 3223, up by a factor 1.1304805331462644
#
# Iteration 8 of 10: The Cell number went from 3223 to 3400, up by a factor 1.0549177784672665
#
# Iteration 9 of 10: The Cell number went from 3400 to 3537, up by a factor 1.0402941176470588
#
# Iteration 10 of 10: The Cell number went from 3537 to 3507, up by a factor 0.991518235793045
#
# Cell number went up by a factor 1.374216300940439
#
# Mesh refined in 0.8822121620178223 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.03625679016113281 s
#
# Starting PDE Solver...
#
# PDE solved in 34.640992164611816
#
# Collecting data from PDE...
#
# Data collected in 1.3628385066986084 s
#
# Process 5: potential has 679 elements.
# Overall time taken for process 5: 42.27579379081726 s
#
# MONDtest_NoFunctions_MPI.py:1042: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# This is process 1 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.8887293338775635 s
#
# The mesh of process 1 has 2589 cells
# Process 1 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2589 to 2721, up by a factor 1.0509849362688297
#
# Iteration 2 of 10: The Cell number went from 2721 to 2801, up by a factor 1.0294009555310548
#
# Iteration 3 of 10: The Cell number went from 2801 to 2888, up by a factor 1.0310603355944306
#
# Iteration 4 of 10: The Cell number went from 2888 to 2788, up by a factor 0.9653739612188366
#
# Iteration 5 of 10: The Cell number went from 2788 to 2976, up by a factor 1.067431850789096
#
# Iteration 6 of 10: The Cell number went from 2976 to 3143, up by a factor 1.0561155913978495
#
# Iteration 7 of 10: The Cell number went from 3143 to 3250, up by a factor 1.034043907095132
#
# Iteration 8 of 10: The Cell number went from 3250 to 3094, up by a factor 0.952
#
# Iteration 9 of 10: The Cell number went from 3094 to 3558, up by a factor 1.149967679379444
#
# Iteration 10 of 10: The Cell number went from 3558 to 3458, up by a factor 0.971894322653176
#
# Cell number went up by a factor 1.335650830436462
#
# Mesh refined in 0.8817837238311768 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.03649330139160156 s
#
# Starting PDE Solver...
#
# PDE solved in 34.64087986946106
#
# Collecting data from PDE...
#
# Data collected in 1.3629488945007324 s
#
# Process 1: potential has 793 elements.
# Overall time taken for process 1: 42.28663778305054 s

# %%
#Creating a folder for each set of parameters we use.

x_total_sorted = np.load('Numpy_Arrays/x_sorted_saved.npy')
y_total_sorted = np.load('Numpy_Arrays/y_sorted_saved.npy')
z_total_sorted = np.load('Numpy_Arrays/z_sorted_saved.npy')
r_total_sorted = np.load('Numpy_Arrays/r_sorted_saved.npy')
potential_total_sorted = np.load('Numpy_Arrays/potential_saved.npy')
source_total_sorted = np.load('Numpy_Arrays/source_saved.npy')
apparent_mass_total_sorted = np.load('Numpy_Arrays/apparent_mass_saved.npy')
dark_mass_total_sorted = np.load('Numpy_Arrays/dark_mass_saved.npy')

# %%
#Defining the radius of the Gaussian containing 99.7% of the total mass
radius_tot = stand_dev_peak/3

#Analytic potential for a MOND homogeneous sphere (good approximation to Gaussian, peaked or wide)
potential_dirac_MOND= sqrt(G*mgb*a0)*np.log(r_total_sorted)

#Analytic potential for a MOND homogeneous sphere. Adding MOND potential at boundary for the offset
potential_sphere_MOND = (np.heaviside(r_total_sorted - radius_tot, 0.5)*sqrt(G*mgb*a0)*np.log(r_total_sorted) +
(np.heaviside(radius_tot - r_total_sorted, 0.5))*(4/3*sqrt(pi/3*a0*G*mgb/volume_out)*np.power(r_total_sorted,3/2)+
sqrt(G*mgb*a0)*ln(radius_tot) - 4/3*sqrt(pi/3*a0*G*mgb/volume_out)*radius_tot**(3/2)))

#Potential for a homogeneous sphere in Newton
potential_sphere_Newton = (np.heaviside(r_total_sorted - radius_tot, 0.5)*(-G*mgb/r_total_sorted) +
(np.heaviside(radius_tot - r_total_sorted, 0.5))*G*mgb/(2*radius_tot**3)*(r_total_sorted**2-
3*radius_tot**2)+sqrt(G*mgb*a0)*ln(domain_size))

#Plotting radial FEM solution and analytic solution on the same plot. We use subplots so'
#we can put multiple axes on the same plot and plot different scales
fig, potential1 = plt.subplots(sharex=True, sharey=True)

color = 'tab:red'
potential1.set_ylabel('FEM', color=color)

potential1.scatter(x_total_sorted, potential_total_sorted, marker = '.', s = 0.5, c = y_total_sorted/y_total_sorted.max(), cmap = 'jet')

potential1.tick_params(axis='y', labelcolor=color)

#UNCOMMENT TO HAVE SEPARATE AXES TO COMPARE SHAPES
# potential2 = potential1.twinx()
color = 'tab:blue'
# potential2.set_ylabel('Analytic', color=color)
plt.plot(r_total_sorted, potential_sphere_MOND, label = 'Homogeneous Sphere MOND', linestyle = '--')
plt.plot(r_total_sorted, potential_sphere_Newton, label = 'Homogeneous Sphere Newton', linestyle = '--')

#It is possible to use Latex directly in the labels by enclosing expressions in $$
# plt.ylabel('$\phi$')

plot_annotations(potential1)

#Formatting plot using the function I made
plot_format(potential1,1,0)

potential1_title = f'potential_1_p'

#Saving the figure in the Figure folder, removed padding arounf with bbox_inches and. This is executed
#by each process, so uncomment if need to see solution from each process separately
# plt.savefig(f'Figures/{potential1_title}.pdf', bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
mgb/(4*pi/3*domain_size**3)
# Out:
# 2.447731038318541e-25

# %%
#Creating objects for plotting
baryonic_mass_object = plot_quantity(source_total_sorted, 'Baryonic', 'r', 2)
apparent_mass_object = plot_quantity(apparent_mass_total_sorted, 'Apparent', 'b', baryonic_mass_object.width/2)
dark_mass_object = plot_quantity(dark_mass_total_sorted, 'Dark', 'g', baryonic_mass_object.width/2)

#Declaring figure with 3 subplots
fig, apparent_mass_plot = plt.subplots(1,3,sharex=True,sharey=True, tight_layout=True)

# #Title of the overall plot
# plt.title('Mass Distributions')

#Limit in the y axis for all subplots
apparent_mass_ylim = (1.1*apparent_mass_total_sorted.min(), 1.1*apparent_mass_total_sorted.max())

#Limits fixed from max and min of the apparent mass density, with 10% free extra space
plt.ylim(1.1*apparent_mass_total_sorted.min(), 1.1*apparent_mass_total_sorted.max())  

plot_together = True

for i, distribution in enumerate([baryonic_mass_object, apparent_mass_object, dark_mass_object]):
#First subplot for the baryonic mass distribution
    (apparent_mass_plot[i].scatter(x_total_sorted, distribution.quantity,  marker = '.', s = 1,
    c = y_total_sorted/y_total_sorted.max(), cmap = 'jet'))
    
    #Title of the subplot
    apparent_mass_plot[i]. set_title(distribution.title)
    
    #format each subplot
    plot_format(apparent_mass_plot[i],1,0)

#Integrating the baryonic distribution radially
baryonic_mass_integrated = np.trapz(apparent_mass_total_sorted*4*pi*r_total_sorted**2, x = r_total_sorted)

#Calculating the total mass by integrating the distribution radially
apparent_mass_integrated = np.trapz(apparent_mass_total_sorted*4*pi*r_total_sorted**2, x = r_total_sorted)

#The total dark matter is given by the difference of apparent and baryonic masses
dark_mass_integrated = apparent_mass_integrated - baryonic_mass_integrated

#Ratio between the integrated baryonic density and the total mass. Should be 1
baryonic_integrated_ratio = baryonic_mass_integrated/mgb

#Ratio between the dark matter and the total mass
dark_integrated_ratio = dark_mass_integrated/mgb

#Ratio between the dark matter and baryonic matter, should be exact same as dark_intergrated_ratio!
dark_baryonic_ratio = dark_mass_integrated/baryonic_mass_integrated

print(f'The mass should be: {mgb/(10**14*ms)}MS. It is {baryonic_mass_integrated/(10**14*ms)}MS\nThe ratio of the integrated masses are:\n baryonic integrated/'
      f'correct mass: {baryonic_integrated_ratio}. This should be 1 \n'
      f'Dark mass/baryonic mass = {dark_integrated_ratio}\n'
      f'Dark mass/ baryonic integrated = {dark_baryonic_ratio}')
# Out:
# <img src="data:image/png;base64,..." width="640">
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# The mass should be: 1.13MS. It is 6.569156082723694MS
# The ratio of the integrated masses are:
#  baryonic integrated/correct mass: 5.8134124625873405. This should be 1
# Dark mass/baryonic mass = 0.0
# Dark mass/ baryonic integrated = 0.0

# %%
#Declaring the parameters needed for the Navarro Frenk White distribution
#The density scale
rho_0 = rho_0

#The scale radius
R_s = domain_size

#Analytical formula for the Navarro Frenk White distribution
NFW_distribution = rho_0/((r_total_sorted/R_s)*(1 + r_total_sorted/R_s)**2)

#The difference between apparent mass and baryonic mass is the dark matter distribution
dark_matter_total_sorted = (apparent_mass_total_sorted-source_total_sorted)

fig, dark_matter_density_plot = plt.subplots()

#Plotting al distributions
for i, distribution in enumerate([apparent_mass_object, dark_mass_object, baryonic_mass_object]):

    #Plotting using the plot_quantity object as for cell above. Using loglog here
    (dark_matter_density_plot.loglog(r_total_sorted, distribution.quantity, c = distribution.color,
                                   linewidth = distribution.width, label = distribution.title))

#Limits fixed from max and min of the apparent mass density, with 10% free extra space
plt.ylim(1.1*dark_matter_total_sorted.min(), 1.1*dark_matter_total_sorted.max())    

#Plotting a Navarro Frenk White dark matter distribution on the same graph but not same axis, so it's
#scale independent
NFW_profile_plot = dark_matter_density_plot.twinx()
color = 'tab:blue'

dark_matter_density_plot.plot(r_total_sorted, NFW_distribution, label = 'NFW profile', linestyle = '--', color='g')

plt.title('Dark Matter Distribution')
# plot_annotations(dark_matter_density_plot)
plot_format(dark_matter_density_plot,1,1)
# Out:
# <img src="data:image/png;base64,..." width="640">
# No handles with labels found to put in legend.
