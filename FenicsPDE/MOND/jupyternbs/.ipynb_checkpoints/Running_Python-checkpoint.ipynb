# %% [markdown]
# # This notebook is used to run the python code through Jupyter as if it was a command line. So we run python files, and can use commands such as mpirun to run stuff in parallel.
# # Need to put a '!' in front of every command meant for the command line

# %%
from dolfin import *

#Increasing the width of the notebook (visual difference only)
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

#importing mshr for all mesh functions
import mshr as mshr

#have to define where to put plots BEFORE importing matplotlib
# %matplotlib notebook

#Importing matplotlib to plot the results
from matplotlib import pyplot as plt

#Importing numpy to work with arrays
import numpy as np

#Importing time to compute how long each segment takes
import time

#Needed to use the 3D scatter
from mpl_toolkits.mplot3d import Axes3D

#Importing all quantities, constants etc used in the calculations
from MONDquantities import *

#Importing all classes I created
from MONDclasses import *

#Importing the functions I made from the MONDfunctions file
from MONDfunctions import *

#Importing all expressions for weak forms, initial guesses/BCs and sources
from MONDexpressions import *
# Out:
# <style>.container { width:100% !important; }</style>

# %%
#Very nice link tutorial for MPI with Python:
#https://rabernat.github.io/research_computing/parallel-programming-with-mpi-for-python.html

#Full MPI documentation for Python:
#https://mpi4py.readthedocs.io/en/stable/

#Creating a group in MPI only including certain processes. Kees said the even ones are the cores, the
#odd ones the other thread available per core, so would be nice to get a communicator of cores only!

#IMPORTANT: It turn out that the error coming from using too much memory doesnt seem to happen when using
#MPI! This error: 'PETSc error code is: 76' This means we can use bigger, better meshes and not be
#limited by memory if we run in parallel

#Converting the notebook to a runnable python file 
# !jupyter nbconvert --to script MONDtest_NoFunctions_MPI.ipynb
# Out:
# [NbConvertApp] Converting notebook MONDtest_NoFunctions_MPI.ipynb to script
# [NbConvertApp] Writing 50751 bytes to MONDtest_NoFunctions_MPI.py

# %%
#Running the full script in parallel using MPI. Optimal number of processes:8. This includes two threads
#per core.
! mpirun -n 8 python3 MONDtest_NoFunctions_MPI.py

#IMPORTANT: when solving for newton_continuous, if we have dregee_PDE = 3 it solves OK.
#However, if we have degree_PDE = 1 we get the error:
#ValueError: zero-size array to reduction operation maximum which has no identity for the 3D plots!
# Out:
# Process 0: Generating mesh with CGAL 3D mesh generator
# Process 0: Computed global bounding box tree with 15 boxes.Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: No Jacobian form specified for nonlinear variational problem.
# Process 0: Differentiating residual form F to obtain Jacobian J = F'.
# Process 5: No Jacobian form specified for nonlinear variational problem.Process 1: No Jacobian form specified for nonlinear variational problem.
# Process 1: Differentiating residual form F to obtain Jacobian J = F'.
# Process 2: No Jacobian form specified for nonlinear variational problem.
# Process 2: Differentiating residual form F to obtain Jacobian J = F'.
# Process 3: No Jacobian form specified for nonlinear variational problem.
# Process 3: Differentiating residual form F to obtain Jacobian J = F'.
# Process 4: No Jacobian form specified for nonlinear variational problem.
# Process 4: Differentiating residual form F to obtain Jacobian J = F'.
# Process 6: No Jacobian form specified for nonlinear variational problem.
# Process 6: Differentiating residual form F to obtain Jacobian J = F'.
# Process 7: No Jacobian form specified for nonlinear variational problem.
# Process 7: Differentiating residual form F to obtain Jacobian J = F'.
#
# Process 5: Differentiating residual form F to obtain Jacobian J = F'.
# Process 0: Solving nonlinear variational problem.
# Process 2: Solving nonlinear variational problem.
# Process 3: Solving nonlinear variational problem.
# Process 4: Solving nonlinear variational problem.
# Process 5: Solving nonlinear variational problem.
# Process 6: Solving nonlinear variational problem.
# Process 7: Solving nonlinear variational problem.
# Process 1: Solving nonlinear variational problem.
#   Process 0: Newton iteration 0: r (abs) = 2.149e+36 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Process 0: Newton iteration 1: r (abs) = 1.445e+24 (tol = 1.000e-10) r (rel) = 6.724e-13 (tol = 1.000e-09)
#   Process 0: Newton solver finished in 1 iterations and 1 linear solver iterations.
# MONDtest_NoFunctions_MPI.py:1019: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# This is process 3 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.7528910636901855 s
#
# The mesh of process 3 has 2566 cells
# Process 3 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2566 to 2615, up by a factor 1.0190958690568979
#
# Iteration 2 of 10: The Cell number went from 2615 to 2861, up by a factor 1.0940726577437858
#
# Iteration 3 of 10: The Cell number went from 2861 to 2687, up by a factor 0.9391821041593849
#
# Iteration 4 of 10: The Cell number went from 2687 to 2924, up by a factor 1.088202456270934
#
# Iteration 5 of 10: The Cell number went from 2924 to 2876, up by a factor 0.9835841313269493
#
# Iteration 6 of 10: The Cell number went from 2876 to 3161, up by a factor 1.099095966620306
#
# Iteration 7 of 10: The Cell number went from 3161 to 3173, up by a factor 1.0037962670041127
#
# Iteration 8 of 10: The Cell number went from 3173 to 3346, up by a factor 1.0545225338796091
#
# Iteration 9 of 10: The Cell number went from 3346 to 3457, up by a factor 1.0331739390316796
#
# Iteration 10 of 10: The Cell number went from 3457 to 3517, up by a factor 1.0173560890945907
#
# Cell number went up by a factor 1.3706157443491815
#
# Mesh refined in 0.8670644760131836 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.07539725303649902 s
#
# Starting PDE Solver...
#
# PDE solved in 7.973273515701294
#
# Collecting data from PDE...
#
# Data collected in 7.929987668991089 s
#
# Process 3: potential has 806 elements.
# Overall time taken for process 3: 20.69249129295349 s
#
# MONDtest_NoFunctions_MPI.py:1019: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# This is process 4 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.7681028842926025 s
#
# The mesh of process 4 has 2615 cells
# Process 4 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2615 to 2720, up by a factor 1.0401529636711282
#
# Iteration 2 of 10: The Cell number went from 2720 to 2737, up by a factor 1.00625
#
# Iteration 3 of 10: The Cell number went from 2737 to 2805, up by a factor 1.0248447204968945
#
# Iteration 4 of 10: The Cell number went from 2805 to 2845, up by a factor 1.014260249554367
#
# Iteration 5 of 10: The Cell number went from 2845 to 3084, up by a factor 1.084007029876977
#
# Iteration 6 of 10: The Cell number went from 3084 to 3112, up by a factor 1.0090791180285343
#
# Iteration 7 of 10: The Cell number went from 3112 to 3033, up by a factor 0.9746143958868895
#
# Iteration 8 of 10: The Cell number went from 3033 to 3373, up by a factor 1.1121002307945929
#
# Iteration 9 of 10: The Cell number went from 3373 to 3450, up by a factor 1.0228283427216127
#
# Iteration 10 of 10: The Cell number went from 3450 to 3232, up by a factor 0.9368115942028985
#
# Cell number went up by a factor 1.235946462715105
#
# Mesh refined in 0.8669769763946533 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.0745704174041748 s
#
# Starting PDE Solver...
#
# PDE solved in 7.974043369293213
#
# Collecting data from PDE...
#
# Data collected in 7.918163776397705 s
#
# Process 4: potential has 733 elements.
# Overall time taken for process 4: 20.708120822906494 s
#
# MONDtest_NoFunctions_MPI.py:1019: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# This is process 5 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.7680773735046387 s
#
# The mesh of process 5 has 2616 cells
# Process 5 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2616 to 2747, up by a factor 1.0500764525993884
#
# Iteration 2 of 10: The Cell number went from 2747 to 2896, up by a factor 1.0542409901710958
#
# Iteration 3 of 10: The Cell number went from 2896 to 2755, up by a factor 0.9513121546961326
#
# Iteration 4 of 10: The Cell number went from 2755 to 2844, up by a factor 1.0323049001814881
#
# Iteration 5 of 10: The Cell number went from 2844 to 3080, up by a factor 1.0829817158931083
#
# Iteration 6 of 10: The Cell number went from 3080 to 3155, up by a factor 1.0243506493506493
#
# Iteration 7 of 10: The Cell number went from 3155 to 3034, up by a factor 0.961648177496038
#
# Iteration 8 of 10: The Cell number went from 3034 to 3374, up by a factor 1.1120632827949901
#
# Iteration 9 of 10: The Cell number went from 3374 to 3450, up by a factor 1.022525192649674
#
# Iteration 10 of 10: The Cell number went from 3450 to 3232, up by a factor 0.9368115942028985
#
# Cell number went up by a factor 1.235474006116208
#
# Mesh refined in 0.8670189380645752 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.07392525672912598 s
#
# Starting PDE Solver...
#
# PDE solved in 7.974545240402222
#
# Collecting data from PDE...
#
# Data collected in 7.918415069580078 s
#
# Process 5: potential has 731 elements.
# Overall time taken for process 5: 20.708401441574097 s
#
# MONDtest_NoFunctions_MPI.py:1019: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# This is process 2 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.768267869949341 s
#
# The mesh of process 2 has 2560 cells
# Process 2 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2560 to 2615, up by a factor 1.021484375
#
# Iteration 2 of 10: The Cell number went from 2615 to 2799, up by a factor 1.0703632887189292
#
# Iteration 3 of 10: The Cell number went from 2799 to 2721, up by a factor 0.9721329046087889
#
# Iteration 4 of 10: The Cell number went from 2721 to 2793, up by a factor 1.0264608599779492
#
# Iteration 5 of 10: The Cell number went from 2793 to 2875, up by a factor 1.029359112065879
#
# Iteration 6 of 10: The Cell number went from 2875 to 3160, up by a factor 1.0991304347826087
#
# Iteration 7 of 10: The Cell number went from 3160 to 3049, up by a factor 0.964873417721519
#
# Iteration 8 of 10: The Cell number went from 3049 to 3345, up by a factor 1.097081010167268
#
# Iteration 9 of 10: The Cell number went from 3345 to 3457, up by a factor 1.0334828101644244
#
# Iteration 10 of 10: The Cell number went from 3457 to 3517, up by a factor 1.0173560890945907
#
# Cell number went up by a factor 1.373828125
#
# Mesh refined in 0.8671774864196777 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.0752108097076416 s
#
# Starting PDE Solver...
#
# PDE solved in 7.97331166267395
#
# Collecting data from PDE...
#
# Data collected in 7.930092096328735 s
#
# Process 2: potential has 804 elements.
# Overall time taken for process 2: 20.709572792053223 s
#
# MONDtest_NoFunctions_MPI.py:1019: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# This is process 7 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.7680916786193848 s
#
# The mesh of process 7 has 2767 cells
# Process 7 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2767 to 2604, up by a factor 0.9410914347668956
#
# Iteration 2 of 10: The Cell number went from 2604 to 2696, up by a factor 1.0353302611367128
#
# Iteration 3 of 10: The Cell number went from 2696 to 2791, up by a factor 1.0352373887240356
#
# Iteration 4 of 10: The Cell number went from 2791 to 2980, up by a factor 1.067717663919742
#
# Iteration 5 of 10: The Cell number went from 2980 to 2906, up by a factor 0.9751677852348993
#
# Iteration 6 of 10: The Cell number went from 2906 to 2922, up by a factor 1.0055058499655884
#
# Iteration 7 of 10: The Cell number went from 2922 to 3201, up by a factor 1.095482546201232
#
# Iteration 8 of 10: The Cell number went from 3201 to 3120, up by a factor 0.9746954076850984
#
# Iteration 9 of 10: The Cell number went from 3120 to 3131, up by a factor 1.003525641025641
#
# Iteration 10 of 10: The Cell number went from 3131 to 3506, up by a factor 1.1197700415202811
#
# Cell number went up by a factor 1.2670762558727864
#
# Mesh refined in 0.86714768409729 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.0756065845489502 s
#
# Starting PDE Solver...
#
# PDE solved in 7.972989559173584
#
# Collecting data from PDE...
#
# Data collected in 7.918234586715698 s
#
# Process 7: potential has 785 elements.
# Overall time taken for process 7: 20.709518432617188 s
#
# MONDtest_NoFunctions_MPI.py:1019: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# This is process 6 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.7680280208587646 s
#
# The mesh of process 6 has 2742 cells
# Process 6 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2742 to 2653, up by a factor 0.9675419401896426
#
# Iteration 2 of 10: The Cell number went from 2653 to 2711, up by a factor 1.0218620429702223
#
# Iteration 3 of 10: The Cell number went from 2711 to 2888, up by a factor 1.0652895610475839
#
# Iteration 4 of 10: The Cell number went from 2888 to 2988, up by a factor 1.0346260387811634
#
# Iteration 5 of 10: The Cell number went from 2988 to 2908, up by a factor 0.9732262382864793
#
# Iteration 6 of 10: The Cell number went from 2908 to 3123, up by a factor 1.0739339752407153
#
# Iteration 7 of 10: The Cell number went from 3123 to 3269, up by a factor 1.0467499199487673
#
# Iteration 8 of 10: The Cell number went from 3269 to 3071, up by a factor 0.9394310186601407
#
# Iteration 9 of 10: The Cell number went from 3071 to 3131, up by a factor 1.0195376098990556
#
# Iteration 10 of 10: The Cell number went from 3131 to 3484, up by a factor 1.112743532417758
#
# Cell number went up by a factor 1.2706053975200584
#
# Mesh refined in 0.8670604228973389 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.07480335235595703 s
#
# Starting PDE Solver...
#
# PDE solved in 7.973795413970947
#
# Collecting data from PDE...
#
# Data collected in 7.918336391448975 s
#
# Process 6: potential has 792 elements.
# Overall time taken for process 6: 20.710295915603638 s
#
# MONDtest_NoFunctions_MPI.py:1019: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# This is process 1 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.768118381500244 s
#
# The mesh of process 1 has 2779 cells
# Process 1 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2779 to 2798, up by a factor 1.0068369917236415
#
# Iteration 2 of 10: The Cell number went from 2798 to 2743, up by a factor 0.9803431022158685
#
# Iteration 3 of 10: The Cell number went from 2743 to 2957, up by a factor 1.078016769959898
#
# Iteration 4 of 10: The Cell number went from 2957 to 2907, up by a factor 0.9830909705782888
#
# Iteration 5 of 10: The Cell number went from 2907 to 3113, up by a factor 1.0708634330925353
#
# Iteration 6 of 10: The Cell number went from 3113 to 2968, up by a factor 0.9534211371667202
#
# Iteration 7 of 10: The Cell number went from 2968 to 3277, up by a factor 1.1041105121293802
#
# Iteration 8 of 10: The Cell number went from 3277 to 3060, up by a factor 0.9337808971620385
#
# Iteration 9 of 10: The Cell number went from 3060 to 3138, up by a factor 1.0254901960784313
#
# Iteration 10 of 10: The Cell number went from 3138 to 3200, up by a factor 1.0197578075207139
#
# Cell number went up by a factor 1.1514933429291112
#
# Mesh refined in 0.8663482666015625 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.07451915740966797 s
#
# Starting PDE Solver...
#
# PDE solved in 7.9745399951934814
#
# Collecting data from PDE...
#
# Data collected in 7.919027090072632 s
#
# Process 1: potential has 614 elements.
# Overall time taken for process 1: 20.712311029434204 s
#
# MONDtest_NoFunctions_MPI.py:1019: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# This is process 0 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.7690184116363525 s
#
# The mesh of process 0 has 2779 cells
# Process 0 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2779 to 2798, up by a factor 1.0068369917236415
#
# Iteration 2 of 10: The Cell number went from 2798 to 2637, up by a factor 0.942458899213724
#
# Iteration 3 of 10: The Cell number went from 2637 to 2952, up by a factor 1.1194539249146758
#
# Iteration 4 of 10: The Cell number went from 2952 to 3045, up by a factor 1.0315040650406504
#
# Iteration 5 of 10: The Cell number went from 3045 to 3048, up by a factor 1.000985221674877
#
# Iteration 6 of 10: The Cell number went from 3048 to 2914, up by a factor 0.9560367454068242
#
# Iteration 7 of 10: The Cell number went from 2914 to 3111, up by a factor 1.0676046671242279
#
# Iteration 8 of 10: The Cell number went from 3111 to 3060, up by a factor 0.9836065573770492
#
# Iteration 9 of 10: The Cell number went from 3060 to 3137, up by a factor 1.0251633986928104
#
# Iteration 10 of 10: The Cell number went from 3137 to 3200, up by a factor 1.020082881734141
#
# Cell number went up by a factor 1.1514933429291112
#
# Mesh refined in 0.8668568134307861 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.07550978660583496 s
#
# Starting PDE Solver...
#
# PDE solved in 7.972875118255615
#
# Collecting data from PDE...
#
# Data collected in 7.915787220001221 s
#
# Process 0: potential has 686 elements.
# Process 0: the overall potential has 5951 elements.
# potential_total has length 6546
# potential_total_no_zeros has length 6546
# x_coords has length: 686
# x_coords_total has length: 6546
# x_total_no_zeros has length: 6546
# Overall time taken for process 0: 20.7231867313385 s

# %%
#Creating a folder for each set of parameters we use.

r_total_sorted = np.load('Numpy_Arrays/r_sorted_saved.npy')
potential_total_sorted = np.load('Numpy_Arrays/potential_saved.npy')
source_total_sorted = np.load('Numpy_Arrays/source_saved.npy')
apparent_mass_total_sorted = np.load('Numpy_Arrays/apparent_mass_saved.npy')
dark_mass_total_sorted = np.load('Numpy_Arrays/dark_mass_saved.npy')

# %%
#Defining the radius of the Gaussian containing 99.7% of the total mass
radius_tot = stand_dev_peak/3

#Analytic potential for a MOND homogeneous sphere (good approximation to Gaussian, peaked or wide)
potential_dirac_MOND= sqrt(G*mgb*a0)*np.log(r_total_sorted)

#Analytic potential for a MOND homogeneous sphere. Adding MOND potential at boundary for the offset
potential_sphere_MOND = (np.heaviside(r_total_sorted - radius_tot, 0.5)*sqrt(G*mgb*a0)*np.log(r_total_sorted) +
(np.heaviside(radius_tot - r_total_sorted, 0.5))*(4/3*sqrt(pi/3*a0*G*mgb/volume_out)*np.power(r_total_sorted,3/2)+
sqrt(G*mgb*a0)*ln(radius_tot) - 4/3*sqrt(pi/3*a0*G*mgb/volume_out)*radius_tot**(3/2)))

#Potential for a homogeneous sphere in Newton
potential_sphere_Newton = (np.heaviside(r_total_sorted - radius_tot, 0.5)*(-G*mgb/r_total_sorted) +
(np.heaviside(radius_tot - r_total_sorted, 0.5))*G*mgb/(2*radius_tot**3)*(r_total_sorted**2-
3*radius_tot**2)+sqrt(G*mgb*a0)*ln(domain_size))

#Plotting radial FEM solution and analytic solution on the same plot. We use subplots so'
#we can put multiple axes on the same plot and plot different scales
fig, potential1 = plt.subplots(sharex=True, sharey=True)

color = 'tab:red'
potential1.set_ylabel('FEM', color=color)

potential1.plot(r_total_sorted, potential_total_sorted, label = 'FEM', color=color, linestyle='-')

potential1.tick_params(axis='y', labelcolor=color)

#UNCOMMENT TO HAVE SEPARATE AXES TO COMPARE SHAPES
# potential2 = potential1.twinx()
color = 'tab:blue'
# potential2.set_ylabel('Analytic', color=color)
plt.plot(r_total_sorted, potential_sphere_MOND, label = 'Homogeneous Sphere MOND', linestyle = '--')
plt.plot(r_total_sorted, potential_sphere_Newton, label = 'Homogeneous Sphere Newton', linestyle = '--')

#It is possible to use Latex directly in the labels by enclosing expressions in $$
# plt.ylabel('$\phi$')

plot_annotations(potential1)

#Formatting plot using the function I made
plot_format(potential1,1,1)

potential1_title = f'potential_1_p'

#Saving the figure in the Figure folder, removed padding arounf with bbox_inches and. This is executed
#by each process, so uncomment if need to see solution from each process separately
# plt.savefig(f'Figures/{potential1_title}.pdf', bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
mgb/(4*pi/3*domain_size**3)
# Out:
# 6.763532931226164e-26

# %%
fig, apparent_mass_plot = plt.subplots()

plot_together = True

#Scaling the mass distribution by 4*pi*G to get rho itself
apparent_mass_plot.plot(r_total_sorted, 1/(4*pi*G)*apparent_mass_total_sorted, label = 'Apparent Mass Distribution')

if plot_together == True:
    
    apparent_mass_plot.plot(r_total_sorted, 1/(4*pi*G)*source_total_sorted, label = 'Baryonic Mass Distribution', linestyle='--')

plt.title('Apparent Mass Distribution')
plot_annotations(apparent_mass_plot)
plot_format(apparent_mass_plot,1,1)

#Integrating the baryonic distribution radially
baryonic_mass_integrated = np.trapz(apparent_mass_total_sorted*4*pi*r_total_sorted**2, x = r_total_sorted)

#Calculating the total mass by integrating the distribution radially
apparent_mass_integrated = np.trapz(apparent_mass_total_sorted*4*pi*r_total_sorted**2, x = r_total_sorted)

#The total dark matter is given by the difference of apparent and baryonic masses
dark_mass_integrated = apparent_mass_integrated - baryonic_mass_integrated

#Ratio between the integrated baryonic density and the total mass. Should be 1
baryonic_integrated_ratio = baryonic_mass_integrated/mgb

#Ratio between the dark matter and the total mass
dark_integrated_ratio = dark_mass_integrated/mgb

#Ratio between the dark matter and baryonic matter, should be exact same as dark_intergrated_ratio!
dark_baryonic_ratio = dark_mass_integrated/baryonic_mass_integrated

print(f'The mass should be: {mgb},\nThe ratio of the integrated masses are:\n baryonic integrated/'
      f'correct mass: {baryonic_integrated_ratio}. This should be 1 \n'
      f'Dark mass/baryonic mass = {dark_integrated_ratio}\n'
      f'Dark mass/ baryonic integrated = {dark_baryonic_ratio}')
# Out:
# <img src="data:image/png;base64,..." width="640">
# The mass should be: 2.24757e+44,
# The ratio of the integrated masses are:
#  baryonic integrated/correct mass: 1833.6576116930482. This should be 1
# Dark mass/baryonic mass = 0.0
# Dark mass/ baryonic integrated = 0.0

# %%
#Declaring the parameters needed for the Navarro Frenk White distribution
#The density scale
rho_0 = 1e-25

#The scale radius
R_s = domain_size*2

#Analytical formula for the Navarro Frenk White distribution
NFW_distribution = rho_0/((r_total_sorted/R_s)*(1 + r_total_sorted/R_s)**2)

#The difference between apparent mass and baryonic mass is the dark matter distribution
dark_matter_total_sorted = (apparent_mass_total_sorted-source_total_sorted)

fig, dark_matter_density_plot = plt.subplots()

dark_matter_density_plot.plot(r_total_sorted, 1/(4*pi*G)*dark_matter_total_sorted, label = 'Dark Matter Distribution')

#Plotting a Navarro Frenk White dark matter distribution on the same graph but not same axis, so it's
#scale independent
NFW_profile_plot = dark_matter_density_plot.twinx()
color = 'tab:blue'

dark_matter_density_plot.plot(r_total_sorted, NFW_distribution, label = 'NFW profile', linestyle = '--', color='r')


if plot_together == True:
    
    dark_matter_density_plot.plot(r_total_sorted, 1/(4*pi*G)*source_total_sorted, label = 'Baryonic Matter Distribution', linestyle='--')

plt.title('Dark Matter Distribution')
plot_annotations(dark_matter_density_plot)
plot_format(dark_matter_density_plot,1,1)
# Out:
# <img src="data:image/png;base64,..." width="640">
