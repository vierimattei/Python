# %% [markdown]
# # This notebook is used to run the python code through Jupyter as if it was a command line. So we run python files, and can use commands such as mpirun to run stuff in parallel.
# # Need to put a '!' in front of every command meant for the command line

# %%
from dolfin import *

#Increasing the width of the notebook (visual difference only)
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

#importing mshr for all mesh functions
import mshr as mshr

#have to define where to put plots BEFORE importing matplotlib
# %matplotlib notebook

#Importing matplotlib to plot the results
from matplotlib import pyplot as plt

#Importing numpy to work with arrays
import numpy as np

import pandas as pd

#Importing time to compute how long each segment takes
import time

#Needed to use the 3D scatter
from mpl_toolkits.mplot3d import Axes3D

#Importing all quantities, constants etc used in the calculations
from MONDquantities import *

#Importing all classes I created
from MONDclasses import *

#Importing the functions I made from the MONDfunctions file
from MONDfunctions import *

#Importing all expressions for weak forms, initial guesses/BCs and sources
from MONDexpressions import *

#I deleted the original table by mistake, but luckily I had the dataframe open in adifferent notebook
#so I saved it as a pickle. Now all I need to do to import it is read the pickle!
df = pd.read_pickle('cluster_data_pickle.pkl')

#Putting each column in its own list to loop over. Scaling rho_0 by 10^22, and rc by kp
cluster_name = df.loc[:, 'name']
cluster_rc = df.loc[:, 'r_c_frame']*kp
cluster_rho0 = df.loc[:, 'rho_0_frame']*10**(-22)
cluster_beta = df.loc[:, 'beta_frame']
# Out:
# <style>.container { width:100% !important; }</style>

# %%
#Very nice link tutorial for MPI with Python:
#https://rabernat.github.io/research_computing/parallel-programming-with-mpi-for-python.html

#Full MPI documentation for Python:
#https://mpi4py.readthedocs.io/en/stable/

#Creating a group in MPI only including certain processes. Kees said the even ones are the cores, the
#odd ones the other thread available per core, so would be nice to get a communicator of cores only!

#IMPORTANT: It turn out that the error coming from using too much memory doesnt seem to happen when using
#MPI! This error: 'PETSc error code is: 76' This means we can use bigger, better meshes and not be
#limited by memory if we run in parallel

#Converting the notebook to a runnable python file 
# !jupyter nbconvert --to script MONDtest_NoFunctions_MPI_LOOP.ipynb
# Out:
# [NbConvertApp] Converting notebook MONDtest_NoFunctions_MPI_LOOP.ipynb to script
# [NbConvertApp] Writing 24334 bytes to MONDtest_NoFunctions_MPI_LOOP.py

# %%
#Running the full script in parallel using MPI. Optimal number of processes:8. This includes two threads
#per core.

! mpirun -n 8 python3 MONDtest_NoFunctions_MPI_LOOP.py

#IMPORTANT: when solving for newton_continuous, if we have dregee_PDE = 3 it solves OK.
#However, if we have degree_PDE = 1 we get the error:
#ValueError: zero-size array to reduction operation maximum which has no identity for the 3D plots!
# Out:
# Process 0: Generating mesh with CGAL 3D mesh generator
# Process 0: Computed global bounding box tree with 15 boxes.Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 1: No Jacobian form specified for nonlinear variational problem.
# Process 1: Differentiating residual form F to obtain Jacobian J = F'.
# Process 5: No Jacobian form specified for nonlinear variational problem.
# Process 5: Differentiating residual form F to obtain Jacobian J = F'.
# Process 7: No Jacobian form specified for nonlinear variational problem.Process 0: No Jacobian form specified for nonlinear variational problem.
# Process 0: Differentiating residual form F to obtain Jacobian J = F'.
# Process 2: No Jacobian form specified for nonlinear variational problem.
# Process 2: Differentiating residual form F to obtain Jacobian J = F'.
# Process 3: No Jacobian form specified for nonlinear variational problem.
# Process 3: Differentiating residual form F to obtain Jacobian J = F'.
# Process 4: No Jacobian form specified for nonlinear variational problem.
# Process 4: Differentiating residual form F to obtain Jacobian J = F'.
# Process 6: No Jacobian form specified for nonlinear variational problem.
# Process 6: Differentiating residual form F to obtain Jacobian J = F'.
#
# Process 7: Differentiating residual form F to obtain Jacobian J = F'.
# Process 0: Solving nonlinear variational problem.
# Process 1: Solving nonlinear variational problem.
# Process 4: Solving nonlinear variational problem.
# Process 5: Solving nonlinear variational problem.
# Process 6: Solving nonlinear variational problem.
# Process 7: Solving nonlinear variational problem.Process 2: Solving nonlinear variational problem.
#
#   Process 0: Newton iteration 0: r (abs) = 1.201e+35 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
# Process 3: Solving nonlinear variational problem.
#   Process 0: Newton iteration 1: r (abs) = 3.282e+20 (tol = 1.000e-10) r (rel) = 2.732e-15 (tol = 1.000e-09)
#   Process 0: Newton solver finished in 1 iterations and 1 linear solver iterations.
# This is process 1 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.7420411109924316 s
#
# The mesh of process 1 has 2573 cells
# Process 1 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2573 to 2814, up by a factor 1.0936649825106879
#
# Iteration 2 of 10: The Cell number went from 2814 to 2731, up by a factor 0.9705046197583511
#
# Iteration 3 of 10: The Cell number went from 2731 to 2742, up by a factor 1.0040278286342
#
# Iteration 4 of 10: The Cell number went from 2742 to 2698, up by a factor 0.9839533187454412
#
# Iteration 5 of 10: The Cell number went from 2698 to 2754, up by a factor 1.0207561156412157
#
# Iteration 6 of 10: The Cell number went from 2754 to 3014, up by a factor 1.0944081336238198
#
# Iteration 7 of 10: The Cell number went from 3014 to 2815, up by a factor 0.9339747843397479
#
# Iteration 8 of 10: The Cell number went from 2815 to 2916, up by a factor 1.035879218472469
#
# Iteration 9 of 10: The Cell number went from 2916 to 3154, up by a factor 1.0816186556927299
#
# Iteration 10 of 10: The Cell number went from 3154 to 3325, up by a factor 1.0542168674698795
#
# Cell number went up by a factor 1.2922658375437233
#
# Mesh refined in 0.8624839782714844 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.0631093978881836 s
#
# Starting PDE Solver...
#
# PDE solved in 0.1176750659942627
#
# Collecting data from PDE...
#
# Data collected in 0.11307096481323242 s
#
# Process 1: potential has 752 elements.
# This is process 2 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.7360751628875732 s
#
# The mesh of process 2 has 2601 cells
# Process 2 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2601 to 2563, up by a factor 0.9853902345251826
#
# Iteration 2 of 10: The Cell number went from 2563 to 2766, up by a factor 1.0792040577448303
#
# Iteration 3 of 10: The Cell number went from 2766 to 2654, up by a factor 0.9595083152566883
#
# Iteration 4 of 10: The Cell number went from 2654 to 2961, up by a factor 1.1156744536548606
#
# Iteration 5 of 10: The Cell number went from 2961 to 2967, up by a factor 1.0020263424518743
#
# Iteration 6 of 10: The Cell number went from 2967 to 2786, up by a factor 0.9389956184698348
#
# Iteration 7 of 10: The Cell number went from 2786 to 3070, up by a factor 1.101938262742283
#
# Iteration 8 of 10: The Cell number went from 3070 to 3095, up by a factor 1.00814332247557
#
# Iteration 9 of 10: The Cell number went from 3095 to 3297, up by a factor 1.0652665589660744
#
# Iteration 10 of 10: The Cell number went from 3297 to 3364, up by a factor 1.0203215043979375
#
# Cell number went up by a factor 1.2933487120338332
#
# Mesh refined in 0.8605184555053711 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.0648491382598877 s
#
# Starting PDE Solver...
#
# PDE solved in 0.11767411231994629
#
# Collecting data from PDE...
#
# Data collected in 0.1130836009979248 s
#
# Process 2: potential has 754 elements.
# This is process 3 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.7393856048583984 s
#
# The mesh of process 3 has 2700 cells
# Process 3 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2700 to 2563, up by a factor 0.9492592592592592
#
# Iteration 2 of 10: The Cell number went from 2563 to 2664, up by a factor 1.0394069449863441
#
# Iteration 3 of 10: The Cell number went from 2664 to 2868, up by a factor 1.0765765765765767
#
# Iteration 4 of 10: The Cell number went from 2868 to 2927, up by a factor 1.0205718270571826
#
# Iteration 5 of 10: The Cell number went from 2927 to 3018, up by a factor 1.031089853091903
#
# Iteration 6 of 10: The Cell number went from 3018 to 2901, up by a factor 0.9612326043737575
#
# Iteration 7 of 10: The Cell number went from 2901 to 3088, up by a factor 1.0644605308514306
#
# Iteration 8 of 10: The Cell number went from 3088 to 3139, up by a factor 1.0165155440414508
#
# Iteration 9 of 10: The Cell number went from 3139 to 3339, up by a factor 1.0637145587766805
#
# Iteration 10 of 10: The Cell number went from 3339 to 3392, up by a factor 1.0158730158730158
#
# Cell number went up by a factor 1.2562962962962962
#
# Mesh refined in 0.859961986541748 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.0652918815612793 s
#
# Starting PDE Solver...
#
# PDE solved in 0.11768507957458496
#
# Collecting data from PDE...
#
# Data collected in 0.11306166648864746 s
#
# Process 3: potential has 768 elements.
# This is process 5 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.742628574371338 s
#
# The mesh of process 5 has 2550 cells
# Process 5 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2550 to 2791, up by a factor 1.0945098039215686
#
# Iteration 2 of 10: The Cell number went from 2791 to 2649, up by a factor 0.94912217843067
#
# Iteration 3 of 10: The Cell number went from 2649 to 2701, up by a factor 1.0196300490751227
#
# Iteration 4 of 10: The Cell number went from 2701 to 2708, up by a factor 1.002591632728619
#
# Iteration 5 of 10: The Cell number went from 2708 to 2997, up by a factor 1.1067208271787297
#
# Iteration 6 of 10: The Cell number went from 2997 to 2831, up by a factor 0.9446112779446113
#
# Iteration 7 of 10: The Cell number went from 2831 to 2922, up by a factor 1.0321441186859768
#
# Iteration 8 of 10: The Cell number went from 2922 to 2972, up by a factor 1.0171115674195756
#
# Iteration 9 of 10: The Cell number went from 2972 to 3398, up by a factor 1.1433378196500672
#
# Iteration 10 of 10: The Cell number went from 3398 to 3504, up by a factor 1.0311948204826369
#
# Cell number went up by a factor 1.3741176470588234
#
# Mesh refined in 0.860004186630249 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.06477928161621094 s
#
# Starting PDE Solver...
#
# PDE solved in 0.11793828010559082
#
# Collecting data from PDE...
#
# Data collected in 0.11287307739257812 s
#
# Process 5: potential has 789 elements.
# This is process 6 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.742072820663452 s
#
# The mesh of process 6 has 2700 cells
# Process 6 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2700 to 2610, up by a factor 0.9666666666666667
#
# Iteration 2 of 10: The Cell number went from 2610 to 2859, up by a factor 1.0954022988505747
#
# Iteration 3 of 10: The Cell number went from 2859 to 2889, up by a factor 1.0104931794333682
#
# Iteration 4 of 10: The Cell number went from 2889 to 2891, up by a factor 1.0006922810661127
#
# Iteration 5 of 10: The Cell number went from 2891 to 2754, up by a factor 0.9526115530958146
#
# Iteration 6 of 10: The Cell number went from 2754 to 3026, up by a factor 1.0987654320987654
#
# Iteration 7 of 10: The Cell number went from 3026 to 3096, up by a factor 1.023132848645076
#
# Iteration 8 of 10: The Cell number went from 3096 to 2973, up by a factor 0.9602713178294574
#
# Iteration 9 of 10: The Cell number went from 2973 to 3153, up by a factor 1.060544904137235
#
# Iteration 10 of 10: The Cell number went from 3153 to 3229, up by a factor 1.0241040279099272
#
# Cell number went up by a factor 1.1959259259259258
#
# Mesh refined in 0.8601806163787842 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.06510186195373535 s
#
# Starting PDE Solver...
#
# PDE solved in 0.11795473098754883
#
# Collecting data from PDE...
#
# Data collected in 0.11288690567016602 s
#
# Process 6: potential has 619 elements.
# This is process 7 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.738670587539673 s
#
# The mesh of process 7 has 2763 cells
# Process 7 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2763 to 2569, up by a factor 0.9297864639884184
#
# Iteration 2 of 10: The Cell number went from 2569 to 2860, up by a factor 1.113273647333593
#
# Iteration 3 of 10: The Cell number went from 2860 to 2890, up by a factor 1.0104895104895104
#
# Iteration 4 of 10: The Cell number went from 2890 to 2821, up by a factor 0.9761245674740484
#
# Iteration 5 of 10: The Cell number went from 2821 to 2758, up by a factor 0.9776674937965261
#
# Iteration 6 of 10: The Cell number went from 2758 to 2991, up by a factor 1.0844815083393764
#
# Iteration 7 of 10: The Cell number went from 2991 to 3063, up by a factor 1.0240722166499499
#
# Iteration 8 of 10: The Cell number went from 3063 to 3115, up by a factor 1.0169768201110023
#
# Iteration 9 of 10: The Cell number went from 3115 to 3091, up by a factor 0.9922953451043338
#
# Iteration 10 of 10: The Cell number went from 3091 to 3229, up by a factor 1.0446457457133613
#
# Cell number went up by a factor 1.1686572566051394
#
# Mesh refined in 0.8603708744049072 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.06484436988830566 s
#
# Starting PDE Solver...
#
# PDE solved in 0.11797237396240234
#
# Collecting data from PDE...
#
# Data collected in 0.11287212371826172 s
#
# Process 7: potential has 680 elements.
# This is process 4 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.7420928478240967 s
#
# The mesh of process 4 has 2550 cells
# Process 4 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2550 to 2799, up by a factor 1.0976470588235294
#
# Iteration 2 of 10: The Cell number went from 2799 to 2648, up by a factor 0.946052161486245
#
# Iteration 3 of 10: The Cell number went from 2648 to 2670, up by a factor 1.008308157099698
#
# Iteration 4 of 10: The Cell number went from 2670 to 2970, up by a factor 1.1123595505617978
#
# Iteration 5 of 10: The Cell number went from 2970 to 2997, up by a factor 1.009090909090909
#
# Iteration 6 of 10: The Cell number went from 2997 to 2789, up by a factor 0.9305972639305973
#
# Iteration 7 of 10: The Cell number went from 2789 to 2821, up by a factor 1.011473646468268
#
# Iteration 8 of 10: The Cell number went from 2821 to 2961, up by a factor 1.0496277915632755
#
# Iteration 9 of 10: The Cell number went from 2961 to 3401, up by a factor 1.1485984464707868
#
# Iteration 10 of 10: The Cell number went from 3401 to 3503, up by a factor 1.029991179064981
#
# Cell number went up by a factor 1.3737254901960785
#
# Mesh refined in 0.8606102466583252 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.06469869613647461 s
#
# Starting PDE Solver...
#
# PDE solved in 0.11792850494384766
#
# Collecting data from PDE...
#
# Data collected in 0.11288094520568848 s
#
# Process 4: potential has 802 elements.
# This is process 0 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.726039171218872 s
#
# The mesh of process 0 has 2763 cells
# Process 0 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2763 to 2788, up by a factor 1.0090481360839667
#
# Iteration 2 of 10: The Cell number went from 2788 to 2790, up by a factor 1.0007173601147776
#
# Iteration 3 of 10: The Cell number went from 2790 to 2885, up by a factor 1.0340501792114696
#
# Iteration 4 of 10: The Cell number went from 2885 to 2697, up by a factor 0.9348353552859618
#
# Iteration 5 of 10: The Cell number went from 2697 to 2767, up by a factor 1.0259547645532072
#
# Iteration 6 of 10: The Cell number went from 2767 to 3013, up by a factor 1.0889049512106974
#
# Iteration 7 of 10: The Cell number went from 3013 to 2815, up by a factor 0.9342847660139396
#
# Iteration 8 of 10: The Cell number went from 2815 to 2858, up by a factor 1.0152753108348136
#
# Iteration 9 of 10: The Cell number went from 2858 to 3123, up by a factor 1.0927221833449965
#
# Iteration 10 of 10: The Cell number went from 3123 to 3488, up by a factor 1.116874799871918
#
# Cell number went up by a factor 1.2623959464350343
#
# Mesh refined in 0.8603086471557617 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.06485986709594727 s
#
# Starting PDE Solver...
#
# PDE solved in 0.11774277687072754
#
# Collecting data from PDE...
#
# Data collected in 0.11299371719360352 s
#
# Process 0: potential has 785 elements.
# Process 0: the overall potential has 5949 elements.
# potential_total has length 8923
# potential_total_no_zeros has length 8700
# x_coords has length: 785
# x_coords_total has length: 8923
# x_total_no_zeros has length: 8899

# %%
#Creating a folder for each set of parameters we use.

potential_total_sorted = np.load(f'database_results/{cluster_name[0]}/potential_{cluster_name[0]}.npy')
source_total_sorted = np.load(f'database_results/{cluster_name[0]}/source_{cluster_name[0]}.npy')
apparent_mass_total_sorted = np.load(f'database_results/{cluster_name[0]}/apparent_{cluster_name[0]}.npy')
dark_mass_total_sorted = np.load(f'database_results/{cluster_name[0]}/dark_mass_{cluster_name[0]}.npy')
x_total_sorted = np.load(f'database_results/{cluster_name[0]}/x_sorted_{cluster_name[0]}.npy')
y_total_sorted = np.load(f'database_results/{cluster_name[0]}/y_sorted_{cluster_name[0]}.npy')
z_total_sorted = np.load(f'database_results/{cluster_name[0]}/z_sorted_{cluster_name[0]}.npy')
r_total_sorted = np.load(f'database_results/{cluster_name[0]}/r_sorted_{cluster_name[0]}.npy')

# %%
# df

# %%
#Defining the radius of the Gaussian containing 99.7% of the total mass
radius_tot = stand_dev_peak/3

#Analytic potential for a MOND homogeneous sphere (good approximation to Gaussian, peaked or wide)
potential_dirac_MOND= sqrt(G*mgb*a0)*np.log(r_total_sorted)

#Analytic potential for a MOND homogeneous sphere. Adding MOND potential at boundary for the offset
potential_sphere_MOND = (np.heaviside(r_total_sorted - radius_tot, 0.5)*sqrt(G*mgb*a0)*np.log(r_total_sorted) +
(np.heaviside(radius_tot - r_total_sorted, 0.5))*(4/3*sqrt(pi/3*a0*G*mgb/volume_out)*np.power(r_total_sorted,3/2)+
sqrt(G*mgb*a0)*ln(radius_tot) - 4/3*sqrt(pi/3*a0*G*mgb/volume_out)*radius_tot**(3/2)))

#Potential for a homogeneous sphere in Newton
potential_sphere_Newton = (np.heaviside(r_total_sorted - radius_tot, 0.5)*(-G*mgb/r_total_sorted) +
(np.heaviside(radius_tot - r_total_sorted, 0.5))*G*mgb/(2*radius_tot**3)*(r_total_sorted**2-
3*radius_tot**2)+sqrt(G*mgb*a0)*ln(domain_size))

#Plotting radial FEM solution and analytic solution on the same plot. We use subplots so'
#we can put multiple axes on the same plot and plot different scales
fig, potential1 = plt.subplots(sharex=True, sharey=True)

color = 'tab:red'
potential1.set_ylabel('FEM', color=color)

potential1.scatter(x_total_sorted, potential_total_sorted, marker = '.', s = 0.5, c = y_total_sorted/y_total_sorted.max(), cmap = 'jet')

potential1.tick_params(axis='y', labelcolor=color)

#UNCOMMENT TO HAVE SEPARATE AXES TO COMPARE SHAPES
# potential2 = potential1.twinx()
color = 'tab:blue'
# potential2.set_ylabel('Analytic', color=color)
plt.plot(r_total_sorted, potential_sphere_MOND, label = 'Homogeneous Sphere MOND', linestyle = '--')
plt.plot(r_total_sorted, potential_sphere_Newton, label = 'Homogeneous Sphere Newton', linestyle = '--')

#It is possible to use Latex directly in the labels by enclosing expressions in $$
# plt.ylabel('$\phi$')

plot_annotations(potential1)

#Formatting plot using the function I made
plot_format(potential1,1,0)

potential1_title = f'potential_1_p'

#Saving the figure in the Figure folder, removed padding arounf with bbox_inches and. This is executed
#by each process, so uncomment if need to see solution from each process separately
# plt.savefig(f'Figures/{potential1_title}.pdf', bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
mgb/(4*pi/3*domain_size**3)
# Out:
# 2.447731038318541e-25

# %%
#Creating objects for plotting
baryonic_mass_object = plot_quantity(source_total_sorted, 'Baryonic', 'r', 2)
apparent_mass_object = plot_quantity(apparent_mass_total_sorted, 'Apparent', 'b', baryonic_mass_object.width/2)
dark_mass_object = plot_quantity(dark_mass_total_sorted, 'Dark', 'g', baryonic_mass_object.width/2)

#Declaring figure with 3 subplots
fig, apparent_mass_plot = plt.subplots(1,3,sharex=True,sharey=True, tight_layout=True)

# #Title of the overall plot
# plt.title('Mass Distributions')

#Limit in the y axis for all subplots
apparent_mass_ylim = (1.1*apparent_mass_total_sorted.min(), 1.1*apparent_mass_total_sorted.max())

# Limits fixed from max and min of the apparent mass density, with 10% free extra space
plt.ylim(1.1*dark_mass_total_sorted.min(), 1.1*apparent_mass_total_sorted.max())  

plot_together = True

for i, distribution in enumerate([baryonic_mass_object, apparent_mass_object, dark_mass_object]):
#First subplot for the baryonic mass distribution
    (apparent_mass_plot[i].scatter(x_total_sorted, distribution.quantity,  marker = '.', s = 1,
    c = y_total_sorted/y_total_sorted.max(), cmap = 'jet'))
    
    #Title of the subplot
    apparent_mass_plot[i]. set_title(distribution.title)
    
    #format each subplot
    plot_format(apparent_mass_plot[i],1,0)

#Integrating the baryonic distribution radially
baryonic_mass_integrated = np.trapz(apparent_mass_total_sorted*4*pi*r_total_sorted**2, x = r_total_sorted)

#Calculating the total mass by integrating the distribution radially
apparent_mass_integrated = np.trapz(apparent_mass_total_sorted*4*pi*r_total_sorted**2, x = r_total_sorted)

#The total dark matter is given by the difference of apparent and baryonic masses
dark_mass_integrated = apparent_mass_integrated - baryonic_mass_integrated

#Ratio between the integrated baryonic density and the total mass. Should be 1
baryonic_integrated_ratio = baryonic_mass_integrated/mgb

#Ratio between the dark matter and the total mass
dark_integrated_ratio = dark_mass_integrated/mgb

#Ratio between the dark matter and baryonic matter, should be exact same as dark_intergrated_ratio!
dark_baryonic_ratio = dark_mass_integrated/baryonic_mass_integrated

print(f'The mass should be: {mgb/(10**14*ms)}MS. It is {baryonic_mass_integrated/(10**14*ms)}MS\nThe ratio of the integrated masses are:\n baryonic integrated/'
      f'correct mass: {baryonic_integrated_ratio}. This should be 1 \n'
      f'Dark mass/baryonic mass = {dark_integrated_ratio}\n'
      f'Dark mass/ baryonic integrated = {dark_baryonic_ratio}')
# Out:
# <img src="data:image/png;base64,..." width="640">
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# The mass should be: 1.13MS. It is 0.0MS
# The ratio of the integrated masses are:
#  baryonic integrated/correct mass: 0.0. This should be 1
# Dark mass/baryonic mass = 0.0
# Dark mass/ baryonic integrated = nan
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:47: RuntimeWarning: invalid value encountered in double_scalars

# %%
beta_mass = (np.trapz(rho_0/(1+(r_total_sorted/r_c)**2)**(3*beta/2)*4*pi*r_total_sorted**2,
                      x = r_total_sorted))

beta_mass_c = (np.trapz(rho_0/(pow(1+(pow(r_total_sorted,2))/pow(r_c,2), 3*beta/2))*4*pi*r_total_sorted**2,
                      x = r_total_sorted)) 

beta_mass/mgb
# Out:
# 1.0301979465021589

# %%
#Declaring the parameters needed for the Navarro Frenk White distribution
#The density scale
rho_0_NFW = rho_0

#The scale radius
R_s = r_c

#Analytical formula for the Navarro Frenk White distribution
NFW_distribution = rho_0/((r_total_sorted/R_s)*(1 + r_total_sorted/R_s)**2)

#The difference between apparent mass and baryonic mass is the dark matter distribution
dark_matter_total_sorted = (apparent_mass_total_sorted-source_total_sorted)

fig, dark_matter_density_plot = plt.subplots()

#Plotting al distributions
for i, distribution in enumerate([apparent_mass_object, dark_mass_object, baryonic_mass_object]):

    #Plotting using the plot_quantity object as for cell above. Using loglog here
    (dark_matter_density_plot.plot(r_total_sorted, distribution.quantity, c = distribution.color,
                                   linewidth = distribution.width, label = distribution.title))

#Limits fixed from max and min of the apparent mass density, with 10% free extra space
plt.ylim(1.1*dark_mass_total_sorted.min(), 1.1*apparent_mass_total_sorted.max())    

#Plotting a Navarro Frenk White dark matter distribution on the same graph but not same axis, so it's
#scale independent
NFW_profile_plot = dark_matter_density_plot.twinx()
color = 'tab:blue'

dark_matter_density_plot.plot(r_total_sorted, NFW_distribution, label = 'NFW profile', linestyle = '--', color='y')

plt.title('Dark Matter Distribution')
# plot_annotations(dark_matter_density_plot)
plot_format(dark_matter_density_plot,1,1)
# Out:
# <img src="data:image/png;base64,..." width="640">
# No handles with labels found to put in legend.
