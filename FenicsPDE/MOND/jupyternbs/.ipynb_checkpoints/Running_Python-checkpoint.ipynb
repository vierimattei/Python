# %% [markdown]
# # This notebook is used to run the python code through Jupyter as if it was a command line. So we run python files, and can use commands such as mpirun to run stuff in parallel.
# # Need to put a '!' in fron of every command meant for the command line

# %%
#Increasing the width of the notebook (visual difference only)
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

#Very nice link tutorial for MPI with Python:
#https://rabernat.github.io/research_computing/parallel-programming-with-mpi-for-python.html

#IMPORTANT: It turn out that the error coming from using too much memory doesnt seem to happen when using
#MPI! This error: 'PETSc error code is: 76' This means we can use bigger, better meshes and not be
#limited by memory if we run in parallel

#Converting the notebook to a runnable python file 
# !jupyter nbconvert --to script MONDtest_NoFunctions_MPI.ipynb
# Out:
# <style>.container { width:100% !important; }</style>
# [NbConvertApp] Converting notebook MONDtest_NoFunctions_MPI.ipynb to script
# [NbConvertApp] Writing 47396 bytes to MONDtest_NoFunctions_MPI.py

# %%
#Running the full script in parallel using MPI. Optimal number of processes:8. This includes two threads
#per core.
! mpirun -n 8 python3 MONDtest_NoFunctions_MPI.py
# Out:
# Process 0: Generating mesh with CGAL 3D mesh generator
# Process 0: Computed global bounding box tree with 15 boxes.Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: No Jacobian form specified for nonlinear variational problem.
# Process 0: Differentiating residual form F to obtain Jacobian J = F'.
# Process 1: No Jacobian form specified for nonlinear variational problem.Process 2: No Jacobian form specified for nonlinear variational problem.
# Process 2: Differentiating residual form F to obtain Jacobian J = F'.
# Process 3: No Jacobian form specified for nonlinear variational problem.
# Process 3: Differentiating residual form F to obtain Jacobian J = F'.
# Process 4: No Jacobian form specified for nonlinear variational problem.
# Process 4: Differentiating residual form F to obtain Jacobian J = F'.
# Process 5: No Jacobian form specified for nonlinear variational problem.
# Process 5: Differentiating residual form F to obtain Jacobian J = F'.
# Process 6: No Jacobian form specified for nonlinear variational problem.
# Process 6: Differentiating residual form F to obtain Jacobian J = F'.
# Process 7: No Jacobian form specified for nonlinear variational problem.
# Process 7: Differentiating residual form F to obtain Jacobian J = F'.
#
# Process 1: Differentiating residual form F to obtain Jacobian J = F'.
# Process 0: Solving nonlinear variational problem.
# Process 2: Solving nonlinear variational problem.
# Process 3: Solving nonlinear variational problem.Process 1: Solving nonlinear variational problem.
#
# Process 6: Solving nonlinear variational problem.
# Process 5: Solving nonlinear variational problem.
# Process 7: Solving nonlinear variational problem.
# Process 4: Solving nonlinear variational problem.
#   Process 0: Newton iteration 0: r (abs) = 2.841e+37 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Process 0: Newton iteration 1: r (abs) = 7.241e+22 (tol = 1.000e-10) r (rel) = 2.549e-15 (tol = 1.000e-09)
#   Process 0: Newton solver finished in 1 iterations and 1 linear solver iterations.
# MONDtest_NoFunctions_MPI.py:956: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# This is process 4 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.953803062438965 s
#
# The mesh of process 4 has 2698 cells
# Starting mesh refinement...
#
# Mesh refined in 9.5367431640625e-06 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.09301900863647461 s
#
# Starting PDE Solver...
#
# PDE solved in 7.18164587020874
#
# Collecting data from PDE...
#
# Data collected in 7.0977232456207275 s
#
# Process 4: potential has 622 elements.
# Overall time taken for process 4: 18.837270259857178 s
#
# MONDtest_NoFunctions_MPI.py:956: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# This is process 2 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.9537079334259033 s
#
# The mesh of process 2 has 2657 cells
# Starting mesh refinement...
#
# Mesh refined in 1.0013580322265625e-05 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.0920095443725586 s
#
# Starting PDE Solver...
#
# PDE solved in 7.182753324508667
#
# Collecting data from PDE...
#
# Data collected in 7.097604513168335 s
#
# Process 2: potential has 635 elements.
# Overall time taken for process 2: 18.842286348342896 s
#
# MONDtest_NoFunctions_MPI.py:956: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# MONDtest_NoFunctions_MPI.py:956: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# This is process 3 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.951700210571289 s
#
# The mesh of process 3 has 2560 cells
# Starting mesh refinement...
#
# Mesh refined in 8.344650268554688e-06 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.09240174293518066 s
#
# Starting PDE Solver...
#
# PDE solved in 7.184646844863892
#
# Collecting data from PDE...
#
# Data collected in 7.096832513809204 s
#
# Process 3: potential has 598 elements.
# Overall time taken for process 3: 18.841275215148926 s
#
# MONDtest_NoFunctions_MPI.py:956: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# This is process 5 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.935633659362793 s
#
# The mesh of process 5 has 2677 cells
# Starting mesh refinement...
#
# Mesh refined in 1.0251998901367188e-05 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.09431123733520508 s
#
# Starting PDE Solver...
#
# PDE solved in 7.180505275726318
#
# Collecting data from PDE...
#
# Data collected in 7.09757399559021 s
#
# Process 5: potential has 620 elements.
# Overall time taken for process 5: 18.826823711395264 s
#
# This is process 0 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.9545490741729736 s
#
# The mesh of process 0 has 2774 cells
# Starting mesh refinement...
#
# Mesh refined in 9.775161743164062e-06 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.09244298934936523 s
#
# Starting PDE Solver...
#
# PDE solved in 7.181961536407471
#
# Collecting data from PDE...
#
# Data collected in 7.097617864608765 s
#
# Process 0: potential has 641 elements.
# Process 0: the overall potential has 4955 elements.
# potential_total has length 5450
# potential_total_no_zeros has length 5450
# x_coords has length: 641
# x_coords_total has length: 5450
# x_total_no_zeros has length: 5445
# Overall time taken for process 0: 18.843175172805786 s
#
# MONDtest_NoFunctions_MPI.py:956: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# This is process 1 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.9539802074432373 s
#
# The mesh of process 1 has 2584 cells
# Starting mesh refinement...
#
# Mesh refined in 1.0728836059570312e-05 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.09180593490600586 s
#
# Starting PDE Solver...
#
# PDE solved in 7.182770729064941
#
# Collecting data from PDE...
#
# Data collected in 7.097726821899414 s
#
# Process 1: potential has 601 elements.
# Overall time taken for process 1: 18.847297191619873 s
#
# MONDtest_NoFunctions_MPI.py:956: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# This is process 6 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.9539804458618164 s
#
# The mesh of process 6 has 2556 cells
# Starting mesh refinement...
#
# Mesh refined in 1.1444091796875e-05 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.09181094169616699 s
#
# Starting PDE Solver...
#
# PDE solved in 7.182756185531616
#
# Collecting data from PDE...
#
# Data collected in 7.097736120223999 s
#
# Process 6: potential has 598 elements.
# Overall time taken for process 6: 18.84979486465454 s
#
# MONDtest_NoFunctions_MPI.py:956: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# This is process 7 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.954017400741577 s
#
# The mesh of process 7 has 2721 cells
# Starting mesh refinement...
#
# Mesh refined in 9.775161743164062e-06 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.09207916259765625 s
#
# Starting PDE Solver...
#
# PDE solved in 7.182720184326172
#
# Collecting data from PDE...
#
# Data collected in 7.097550868988037 s
#
# Process 7: potential has 640 elements.
# Overall time taken for process 7: 18.851390600204468 s
