# %% [markdown]
# # This notebook is used to run the python code through Jupyter as if it was a command line. So we run python files, and can use commands such as mpirun to run stuff in parallel.
# # Need to put a '!' in front of every command meant for the command line

# %%
from dolfin import *

#Increasing the width of the notebook (visual difference only)
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

#importing mshr for all mesh functions
import mshr as mshr

#have to define where to put plots BEFORE importing matplotlib
# %matplotlib notebook

#Importing matplotlib to plot the results
from matplotlib import pyplot as plt

#Importing numpy to work with arrays
import numpy as np

#Importing time to compute how long each segment takes
import time

#Needed to use the 3D scatter
from mpl_toolkits.mplot3d import Axes3D

#Importing all quantities, constants etc used in the calculations
from MONDquantities import *

#Importing all classes I created
from MONDclasses import *

#Importing the functions I made from the MONDfunctions file
from MONDfunctions import *

#Importing all expressions for weak forms, initial guesses/BCs and sources
from MONDexpressions import *
# Out:
# <style>.container { width:100% !important; }</style>

# %%
#Very nice link tutorial for MPI with Python:
#https://rabernat.github.io/research_computing/parallel-programming-with-mpi-for-python.html

#Full MPI documentation for Python:
#https://mpi4py.readthedocs.io/en/stable/

#Creating a group in MPI only including certain processes. Kees said the even ones are the cores, the
#odd ones the other thread available per core, so would be nice to get a communicator of cores only!

#IMPORTANT: It turn out that the error coming from using too much memory doesnt seem to happen when using
#MPI! This error: 'PETSc error code is: 76' This means we can use bigger, better meshes and not be
#limited by memory if we run in parallel

#Converting the notebook to a runnable python file 
# !jupyter nbconvert --to script MONDtest_NoFunctions_MPI.ipynb
# Out:
# [NbConvertApp] Converting notebook MONDtest_NoFunctions_MPI.ipynb to script
# [NbConvertApp] Writing 50856 bytes to MONDtest_NoFunctions_MPI.py

# %%
#Running the full script in parallel using MPI. Optimal number of processes:8. This includes two threads
#per core.
! mpirun -n 8 python3 MONDtest_NoFunctions_MPI.py

#IMPORTANT: when solving for newton_continuous, if we have dregee_PDE = 3 it solves OK.
#However, if we have degree_PDE = 1 we get the error:
#ValueError: zero-size array to reduction operation maximum which has no identity for the 3D plots!
# Out:
# Process 0: Generating mesh with CGAL 3D mesh generator
# Process 0: Computed global bounding box tree with 15 boxes.Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.Process 7: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.
# Process 3: Computed global bounding box tree with 15 boxes.
# Process 4: Computed global bounding box tree with 15 boxes.Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
# Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 0: Computed global bounding box tree with 15 boxes.
# Process 1: Computed global bounding box tree with 15 boxes.
# Process 2: Computed global bounding box tree with 15 boxes.Process 4: Computed global bounding box tree with 15 boxes.
# Process 5: Computed global bounding box tree with 15 boxes.
# Process 6: Computed global bounding box tree with 15 boxes.
#
# Process 3: Computed global bounding box tree with 15 boxes.Process 7: Computed global bounding box tree with 15 boxes.
#
# Process 2: No Jacobian form specified for nonlinear variational problem.Process 3: No Jacobian form specified for nonlinear variational problem.
# Process 3: Differentiating residual form F to obtain Jacobian J = F'.
# Process 5: No Jacobian form specified for nonlinear variational problem.
# Process 5: Differentiating residual form F to obtain Jacobian J = F'.
# Process 6: No Jacobian form specified for nonlinear variational problem.
# Process 6: Differentiating residual form F to obtain Jacobian J = F'.
# Process 4: No Jacobian form specified for nonlinear variational problem.
# Process 4: Differentiating residual form F to obtain Jacobian J = F'.
# Process 7: No Jacobian form specified for nonlinear variational problem.
# Process 7: Differentiating residual form F to obtain Jacobian J = F'.
#
# Process 2: Differentiating residual form F to obtain Jacobian J = F'.
# Process 0: No Jacobian form specified for nonlinear variational problem.Process 1: No Jacobian form specified for nonlinear variational problem.
# Process 1: Differentiating residual form F to obtain Jacobian J = F'.
#
# Process 0: Differentiating residual form F to obtain Jacobian J = F'.
# Process 0: Solving nonlinear variational problem.
# Process 4: Solving nonlinear variational problem.
# Process 5: Solving nonlinear variational problem.
# Process 1: Solving nonlinear variational problem.
# Process 7: Solving nonlinear variational problem.
# Process 2: Solving nonlinear variational problem.
# Process 6: Solving nonlinear variational problem.Process 3: Solving nonlinear variational problem.
#
#   Process 0: Newton iteration 0: r (abs) = 8.407e+33 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Process 0: Newton iteration 1: r (abs) = 2.366e+32 (tol = 1.000e-10) r (rel) = 2.814e-02 (tol = 1.000e-09)
#   Process 0: Newton iteration 2: r (abs) = 7.363e+29 (tol = 1.000e-10) r (rel) = 8.758e-05 (tol = 1.000e-09)
#   Process 0: Newton iteration 3: r (abs) = 6.538e+26 (tol = 1.000e-10) r (rel) = 7.776e-08 (tol = 1.000e-09)
#   Process 0: Newton iteration 4: r (abs) = 4.975e+21 (tol = 1.000e-10) r (rel) = 5.918e-13 (tol = 1.000e-09)
#   Process 0: Newton solver finished in 4 iterations and 4 linear solver iterations.
# MONDtest_NoFunctions_MPI.py:1023: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# MONDtest_NoFunctions_MPI.py:1109: RuntimeWarning: divide by zero encountered in true_divide
#   dark_matter_ratio_sorted = (apparent_mass_distribution_sorted/source_sorted)
# This is process 5 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.8880300521850586 s
#
# The mesh of process 5 has 2586 cells
# Process 5 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2586 to 2783, up by a factor 1.0761794276875483
#
# Iteration 2 of 10: The Cell number went from 2783 to 2681, up by a factor 0.9633489040603666
#
# Iteration 3 of 10: The Cell number went from 2681 to 2826, up by a factor 1.0540842969041402
#
# Iteration 4 of 10: The Cell number went from 2826 to 3009, up by a factor 1.064755838641189
#
# Iteration 5 of 10: The Cell number went from 3009 to 2940, up by a factor 0.9770687936191426
#
# Iteration 6 of 10: The Cell number went from 2940 to 3230, up by a factor 1.098639455782313
#
# Iteration 7 of 10: The Cell number went from 3230 to 3172, up by a factor 0.9820433436532507
#
# Iteration 8 of 10: The Cell number went from 3172 to 3400, up by a factor 1.0718789407313998
#
# Iteration 9 of 10: The Cell number went from 3400 to 3458, up by a factor 1.0170588235294118
#
# Iteration 10 of 10: The Cell number went from 3458 to 3905, up by a factor 1.1292654713707346
#
# Cell number went up by a factor 1.5100541376643464
#
# Mesh refined in 0.9072651863098145 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.027297496795654297 s
#
# Starting PDE Solver...
#
# PDE solved in 15.929020404815674
#
# Collecting data from PDE...
#
# Data collected in 1.364306926727295 s
#
# Process 5: potential has 881 elements.
# Overall time taken for process 5: 22.191272974014282 s
#
# MONDtest_NoFunctions_MPI.py:1023: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# MONDtest_NoFunctions_MPI.py:1109: RuntimeWarning: divide by zero encountered in true_divide
#   dark_matter_ratio_sorted = (apparent_mass_distribution_sorted/source_sorted)
# /usr/local/lib/python3.6/dist-packages/matplotlib/contour.py:1243: UserWarning: No contour levels were found within the data range.
#   warnings.warn("No contour levels were found"
# MONDtest_NoFunctions_MPI.py:1023: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# MONDtest_NoFunctions_MPI.py:1109: RuntimeWarning: divide by zero encountered in true_divide
#   dark_matter_ratio_sorted = (apparent_mass_distribution_sorted/source_sorted)
# /usr/local/lib/python3.6/dist-packages/matplotlib/contour.py:1243: UserWarning: No contour levels were found within the data range.
#   warnings.warn("No contour levels were found"
# This is process 2 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.888272523880005 s
#
# The mesh of process 2 has 2676 cells
# Process 2 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2676 to 2809, up by a factor 1.0497010463378176
#
# Iteration 2 of 10: The Cell number went from 2809 to 2868, up by a factor 1.021003915984336
#
# Iteration 3 of 10: The Cell number went from 2868 to 2896, up by a factor 1.00976290097629
#
# Iteration 4 of 10: The Cell number went from 2896 to 2894, up by a factor 0.9993093922651933
#
# Iteration 5 of 10: The Cell number went from 2894 to 3074, up by a factor 1.0621976503109882
#
# Iteration 6 of 10: The Cell number went from 3074 to 3229, up by a factor 1.0504229017566689
#
# Iteration 7 of 10: The Cell number went from 3229 to 3299, up by a factor 1.0216785382471354
#
# Iteration 8 of 10: The Cell number went from 3299 to 3376, up by a factor 1.023340406183692
#
# Iteration 9 of 10: The Cell number went from 3376 to 3485, up by a factor 1.03228672985782
#
# Iteration 10 of 10: The Cell number went from 3485 to 3623, up by a factor 1.0395982783357245
#
# Cell number went up by a factor 1.3538863976083706
#
# Mesh refined in 0.9072766304016113 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.027250051498413086 s
#
# Starting PDE Solver...
#
# PDE solved in 15.928885459899902
#
# Collecting data from PDE...
#
# Data collected in 1.3645439147949219 s
#
# Process 2: potential has 844 elements.
# Overall time taken for process 2: 22.19319772720337 s
#
# This is process 4 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.888148784637451 s
#
# The mesh of process 4 has 2658 cells
# Process 4 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2658 to 2620, up by a factor 0.9857035364936042
#
# Iteration 2 of 10: The Cell number went from 2620 to 2658, up by a factor 1.0145038167938931
#
# Iteration 3 of 10: The Cell number went from 2658 to 2843, up by a factor 1.0696012039127163
#
# Iteration 4 of 10: The Cell number went from 2843 to 2932, up by a factor 1.0313049595497714
#
# Iteration 5 of 10: The Cell number went from 2932 to 2851, up by a factor 0.9723738062755798
#
# Iteration 6 of 10: The Cell number went from 2851 to 3150, up by a factor 1.104875482286917
#
# Iteration 7 of 10: The Cell number went from 3150 to 3064, up by a factor 0.9726984126984127
#
# Iteration 8 of 10: The Cell number went from 3064 to 3249, up by a factor 1.060378590078329
#
# Iteration 9 of 10: The Cell number went from 3249 to 3439, up by a factor 1.0584795321637428
#
# Iteration 10 of 10: The Cell number went from 3439 to 3597, up by a factor 1.0459435882523989
#
# Cell number went up by a factor 1.353273137697517
#
# Mesh refined in 0.9072797298431396 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.027042388916015625 s
#
# Starting PDE Solver...
#
# PDE solved in 15.928704023361206
#
# Collecting data from PDE...
#
# Data collected in 1.3648927211761475 s
#
# Process 4: potential has 811 elements.
# Overall time taken for process 4: 22.193100452423096 s
#
# MONDtest_NoFunctions_MPI.py:1023: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# MONDtest_NoFunctions_MPI.py:1109: RuntimeWarning: divide by zero encountered in true_divide
#   dark_matter_ratio_sorted = (apparent_mass_distribution_sorted/source_sorted)
# /usr/local/lib/python3.6/dist-packages/matplotlib/contour.py:1243: UserWarning: No contour levels were found within the data range.
#   warnings.warn("No contour levels were found"
# This is process 6 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.8880198001861572 s
#
# The mesh of process 6 has 2721 cells
# Process 6 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2721 to 2764, up by a factor 1.015803013597942
#
# Iteration 2 of 10: The Cell number went from 2764 to 2797, up by a factor 1.0119392185238785
#
# Iteration 3 of 10: The Cell number went from 2797 to 2797, up by a factor 1.0
#
# Iteration 4 of 10: The Cell number went from 2797 to 2787, up by a factor 0.9964247407937076
#
# Iteration 5 of 10: The Cell number went from 2787 to 3095, up by a factor 1.110513096519555
#
# Iteration 6 of 10: The Cell number went from 3095 to 2985, up by a factor 0.9644588045234249
#
# Iteration 7 of 10: The Cell number went from 2985 to 3280, up by a factor 1.0988274706867671
#
# Iteration 8 of 10: The Cell number went from 3280 to 3320, up by a factor 1.0121951219512195
#
# Iteration 9 of 10: The Cell number went from 3320 to 3312, up by a factor 0.9975903614457832
#
# Iteration 10 of 10: The Cell number went from 3312 to 3813, up by a factor 1.151268115942029
#
# Cell number went up by a factor 1.4013230429988974
#
# Mesh refined in 0.9071981906890869 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.027336597442626953 s
#
# Starting PDE Solver...
#
# PDE solved in 15.928896188735962
#
# Collecting data from PDE...
#
# Data collected in 1.364488124847412 s
#
# Process 6: potential has 841 elements.
# Overall time taken for process 6: 22.19365906715393 s
#
# MONDtest_NoFunctions_MPI.py:1023: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# MONDtest_NoFunctions_MPI.py:1109: RuntimeWarning: divide by zero encountered in true_divide
#   dark_matter_ratio_sorted = (apparent_mass_distribution_sorted/source_sorted)
# /usr/local/lib/python3.6/dist-packages/matplotlib/contour.py:1243: UserWarning: No contour levels were found within the data range.
#   warnings.warn("No contour levels were found"
# This is process 3 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.876751661300659 s
#
# The mesh of process 3 has 2709 cells
# Process 3 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2709 to 2809, up by a factor 1.0369139904023625
#
# Iteration 2 of 10: The Cell number went from 2809 to 2869, up by a factor 1.0213599145603418
#
# Iteration 3 of 10: The Cell number went from 2869 to 2931, up by a factor 1.0216103171836877
#
# Iteration 4 of 10: The Cell number went from 2931 to 2831, up by a factor 0.9658819515523712
#
# Iteration 5 of 10: The Cell number went from 2831 to 3099, up by a factor 1.0946661956905688
#
# Iteration 6 of 10: The Cell number went from 3099 to 3234, up by a factor 1.0435624394966119
#
# Iteration 7 of 10: The Cell number went from 3234 to 3197, up by a factor 0.9885590599876314
#
# Iteration 8 of 10: The Cell number went from 3197 to 3377, up by a factor 1.0563027838598686
#
# Iteration 9 of 10: The Cell number went from 3377 to 3483, up by a factor 1.0313888066331063
#
# Iteration 10 of 10: The Cell number went from 3483 to 3623, up by a factor 1.0401952339936835
#
# Cell number went up by a factor 1.337393872277593
#
# Mesh refined in 0.9071476459503174 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.027219295501708984 s
#
# Starting PDE Solver...
#
# PDE solved in 15.929021120071411
#
# Collecting data from PDE...
#
# Data collected in 1.3645448684692383 s
#
# Process 3: potential has 818 elements.
# Overall time taken for process 3: 22.182920217514038 s
#
# MONDtest_NoFunctions_MPI.py:1023: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# MONDtest_NoFunctions_MPI.py:1109: RuntimeWarning: divide by zero encountered in true_divide
#   dark_matter_ratio_sorted = (apparent_mass_distribution_sorted/source_sorted)
# /usr/local/lib/python3.6/dist-packages/matplotlib/contour.py:1243: UserWarning: No contour levels were found within the data range.
#   warnings.warn("No contour levels were found"
# This is process 7 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.887962579727173 s
#
# The mesh of process 7 has 2764 cells
# Process 7 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2764 to 2611, up by a factor 0.9446454413892909
#
# Iteration 2 of 10: The Cell number went from 2611 to 2880, up by a factor 1.1030256606664113
#
# Iteration 3 of 10: The Cell number went from 2880 to 2893, up by a factor 1.004513888888889
#
# Iteration 4 of 10: The Cell number went from 2893 to 2861, up by a factor 0.9889388178361562
#
# Iteration 5 of 10: The Cell number went from 2861 to 3014, up by a factor 1.0534778049632996
#
# Iteration 6 of 10: The Cell number went from 3014 to 2986, up by a factor 0.9907100199071002
#
# Iteration 7 of 10: The Cell number went from 2986 to 3150, up by a factor 1.0549229738780979
#
# Iteration 8 of 10: The Cell number went from 3150 to 3125, up by a factor 0.9920634920634921
#
# Iteration 9 of 10: The Cell number went from 3125 to 3275, up by a factor 1.048
#
# Iteration 10 of 10: The Cell number went from 3275 to 3661, up by a factor 1.1178625954198473
#
# Cell number went up by a factor 1.3245296671490594
#
# Mesh refined in 0.9072561264038086 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.02974247932434082 s
#
# Starting PDE Solver...
#
# PDE solved in 15.926498889923096
#
# Collecting data from PDE...
#
# Data collected in 1.3645362854003906 s
#
# Process 7: potential has 831 elements.
# Overall time taken for process 7: 22.194947957992554 s
#
# MONDtest_NoFunctions_MPI.py:1023: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# MONDtest_NoFunctions_MPI.py:1109: RuntimeWarning: divide by zero encountered in true_divide
#   dark_matter_ratio_sorted = (apparent_mass_distribution_sorted/source_sorted)
# This is process 0 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.888986349105835 s
#
# The mesh of process 0 has 2670 cells
# Process 0 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2670 to 2613, up by a factor 0.9786516853932584
#
# Iteration 2 of 10: The Cell number went from 2613 to 2708, up by a factor 1.036356678147723
#
# Iteration 3 of 10: The Cell number went from 2708 to 2709, up by a factor 1.0003692762186116
#
# Iteration 4 of 10: The Cell number went from 2709 to 2793, up by a factor 1.0310077519379846
#
# Iteration 5 of 10: The Cell number went from 2793 to 2863, up by a factor 1.0250626566416041
#
# Iteration 6 of 10: The Cell number went from 2863 to 2950, up by a factor 1.030387705204331
#
# Iteration 7 of 10: The Cell number went from 2950 to 3206, up by a factor 1.0867796610169491
#
# Iteration 8 of 10: The Cell number went from 3206 to 3150, up by a factor 0.982532751091703
#
# Iteration 9 of 10: The Cell number went from 3150 to 3192, up by a factor 1.0133333333333334
#
# Iteration 10 of 10: The Cell number went from 3192 to 3729, up by a factor 1.1682330827067668
#
# Cell number went up by a factor 1.3966292134831462
#
# Mesh refined in 0.9069461822509766 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.0272064208984375 s
#
# Starting PDE Solver...
#
# PDE solved in 15.928061246871948
#
# Collecting data from PDE...
#
# Data collected in 1.364095687866211 s
#
# Process 0: potential has 766 elements.
# Process 0: the overall potential has 6534 elements.
# potential_total has length 9801
# potential_total_no_zeros has length 9801
# x_coords has length: 766
# x_coords_total has length: 9801
# x_total_no_zeros has length: 8634
# Overall time taken for process 0: 22.201193809509277 s
#
# MONDtest_NoFunctions_MPI.py:1023: RuntimeWarning: divide by zero encountered in true_divide
#   acceleration_error = np.abs((acceleration_magnitude_sorted - acceleration_dirac_analytic)/acceleration_magnitude_sorted)
# This is process 1 out of 7
# Starting mesh generation...
#
# Mesh generated in 2.8880343437194824 s
#
# The mesh of process 1 has 2674 cells
# Process 1 about to refine
# Starting mesh refinement...
#
# Iteration 1 of 10: The Cell number went from 2674 to 2646, up by a factor 0.9895287958115183
#
# Iteration 2 of 10: The Cell number went from 2646 to 2660, up by a factor 1.0052910052910053
#
# Iteration 3 of 10: The Cell number went from 2660 to 2710, up by a factor 1.018796992481203
#
# Iteration 4 of 10: The Cell number went from 2710 to 3036, up by a factor 1.1202952029520294
#
# Iteration 5 of 10: The Cell number went from 3036 to 2978, up by a factor 0.9808959156785244
#
# Iteration 6 of 10: The Cell number went from 2978 to 2938, up by a factor 0.9865681665547347
#
# Iteration 7 of 10: The Cell number went from 2938 to 3076, up by a factor 1.0469707283866576
#
# Iteration 8 of 10: The Cell number went from 3076 to 3150, up by a factor 1.0240572171651496
#
# Iteration 9 of 10: The Cell number went from 3150 to 3191, up by a factor 1.013015873015873
#
# Iteration 10 of 10: The Cell number went from 3191 to 3858, up by a factor 1.2090253838921967
#
# Cell number went up by a factor 1.4427823485415108
#
# Mesh refined in 0.906686544418335 s
#
# Rearranging mesh data
#
# Mesh data rearranged in 0.02765941619873047 s
#
# Starting PDE Solver...
#
# PDE solved in 15.928417921066284
#
# Collecting data from PDE...
#
# Data collected in 1.363987922668457 s
#
# Process 1: potential has 742 elements.
# Overall time taken for process 1: 22.209216594696045 s

# %%
#Creating a folder for each set of parameters we use.

r_total_sorted = np.load('Numpy_Arrays/r_sorted_saved.npy')
potential_total_sorted = np.load('Numpy_Arrays/potential_saved.npy')
source_total_sorted = np.load('Numpy_Arrays/source_saved.npy')
apparent_mass_total_sorted = np.load('Numpy_Arrays/apparent_mass_saved.npy')
dark_mass_total_sorted = np.load('Numpy_Arrays/dark_mass_saved.npy')

# %%
#Defining the radius of the Gaussian containing 99.7% of the total mass
radius_tot = stand_dev_peak/3

#Analytic potential for a MOND homogeneous sphere (good approximation to Gaussian, peaked or wide)
potential_dirac_MOND= sqrt(G*mgb*a0)*np.log(r_total_sorted)

#Analytic potential for a MOND homogeneous sphere. Adding MOND potential at boundary for the offset
potential_sphere_MOND = (np.heaviside(r_total_sorted - radius_tot, 0.5)*sqrt(G*mgb*a0)*np.log(r_total_sorted) +
(np.heaviside(radius_tot - r_total_sorted, 0.5))*(4/3*sqrt(pi/3*a0*G*mgb/volume_out)*np.power(r_total_sorted,3/2)+
sqrt(G*mgb*a0)*ln(radius_tot) - 4/3*sqrt(pi/3*a0*G*mgb/volume_out)*radius_tot**(3/2)))

#Potential for a homogeneous sphere in Newton
potential_sphere_Newton = (np.heaviside(r_total_sorted - radius_tot, 0.5)*(-G*mgb/r_total_sorted) +
(np.heaviside(radius_tot - r_total_sorted, 0.5))*G*mgb/(2*radius_tot**3)*(r_total_sorted**2-
3*radius_tot**2)+sqrt(G*mgb*a0)*ln(domain_size))

#Plotting radial FEM solution and analytic solution on the same plot. We use subplots so'
#we can put multiple axes on the same plot and plot different scales
fig, potential1 = plt.subplots(sharex=True, sharey=True)

color = 'tab:red'
potential1.set_ylabel('FEM', color=color)

potential1.plot(r_total_sorted, potential_total_sorted, label = 'FEM', color=color, linestyle='-')

potential1.tick_params(axis='y', labelcolor=color)

#UNCOMMENT TO HAVE SEPARATE AXES TO COMPARE SHAPES
# potential2 = potential1.twinx()
color = 'tab:blue'
# potential2.set_ylabel('Analytic', color=color)
plt.plot(r_total_sorted, potential_sphere_MOND, label = 'Homogeneous Sphere MOND', linestyle = '--')
plt.plot(r_total_sorted, potential_sphere_Newton, label = 'Homogeneous Sphere Newton', linestyle = '--')

#It is possible to use Latex directly in the labels by enclosing expressions in $$
# plt.ylabel('$\phi$')

plot_annotations(potential1)

#Formatting plot using the function I made
plot_format(potential1,1,1)

potential1_title = f'potential_1_p'

#Saving the figure in the Figure folder, removed padding arounf with bbox_inches and. This is executed
#by each process, so uncomment if need to see solution from each process separately
# plt.savefig(f'Figures/{potential1_title}.pdf', bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
mgb/(4*pi/3*domain_size**3)
# Out:
# 2.447731038318541e-25

# %%
fig, apparent_mass_plot = plt.subplots()

plot_together = True

#Scaling the mass distribution by 4*pi*G to get rho itself
apparent_mass_plot.plot(r_total_sorted, 1/(4*pi*G)*apparent_mass_total_sorted, label = 'Apparent Mass Distribution')

if plot_together == True:
    
    apparent_mass_plot.plot(r_total_sorted, 1/(4*pi*G)*source_total_sorted, label = 'Baryonic Mass Distribution', linestyle='--')

plt.title('Apparent Mass Distribution')
plot_annotations(apparent_mass_plot)
plot_format(apparent_mass_plot,1,1)

#Integrating the baryonic distribution radially
baryonic_mass_integrated = np.trapz(apparent_mass_total_sorted*4*pi*r_total_sorted**2, x = r_total_sorted)

#Calculating the total mass by integrating the distribution radially
apparent_mass_integrated = np.trapz(apparent_mass_total_sorted*4*pi*r_total_sorted**2, x = r_total_sorted)

#The total dark matter is given by the difference of apparent and baryonic masses
dark_mass_integrated = apparent_mass_integrated - baryonic_mass_integrated

#Ratio between the integrated baryonic density and the total mass. Should be 1
baryonic_integrated_ratio = baryonic_mass_integrated/mgb

#Ratio between the dark matter and the total mass
dark_integrated_ratio = dark_mass_integrated/mgb

#Ratio between the dark matter and baryonic matter, should be exact same as dark_intergrated_ratio!
dark_baryonic_ratio = dark_mass_integrated/baryonic_mass_integrated

print(f'The mass should be: {mgb/(10**14*ms)}MS. It is {baryonic_mass_integrated/(10**14*ms)}MS\nThe ratio of the integrated masses are:\n baryonic integrated/'
      f'correct mass: {baryonic_integrated_ratio}. This should be 1 \n'
      f'Dark mass/baryonic mass = {dark_integrated_ratio}\n'
      f'Dark mass/ baryonic integrated = {dark_baryonic_ratio}')
# Out:
# <img src="data:image/png;base64,..." width="640">
# The mass should be: 1.13MS. It is 6.0348006658681MS
# The ratio of the integrated masses are:
#  baryonic integrated/correct mass: 5.3405315627151335. This should be 1
# Dark mass/baryonic mass = 0.0
# Dark mass/ baryonic integrated = 0.0

# %%
#Declaring the parameters needed for the Navarro Frenk White distribution
#The density scale
rho_0 = 1e-25

#The scale radius
R_s = domain_size*2

#Analytical formula for the Navarro Frenk White distribution
NFW_distribution = rho_0/((r_total_sorted/R_s)*(1 + r_total_sorted/R_s)**2)

#The difference between apparent mass and baryonic mass is the dark matter distribution
dark_matter_total_sorted = (apparent_mass_total_sorted-source_total_sorted)

fig, dark_matter_density_plot = plt.subplots()

dark_matter_density_plot.plot(r_total_sorted, 1/(4*pi*G)*dark_matter_total_sorted, label = 'Dark Matter Distribution')

#Plotting a Navarro Frenk White dark matter distribution on the same graph but not same axis, so it's
#scale independent
NFW_profile_plot = dark_matter_density_plot.twinx()
color = 'tab:blue'

dark_matter_density_plot.plot(r_total_sorted, NFW_distribution, label = 'NFW profile', linestyle = '--', color='r')


if plot_together == True:
    
    dark_matter_density_plot.plot(r_total_sorted, 1/(4*pi*G)*source_total_sorted, label = 'Baryonic Matter Distribution', linestyle='--')

plt.title('Dark Matter Distribution')
plot_annotations(dark_matter_density_plot)
plot_format(dark_matter_density_plot,1,1)
# Out:
# <img src="data:image/png;base64,..." width="640">
